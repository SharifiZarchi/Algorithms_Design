# %%
# %%html
# <style>
# p {
#     font-family: IranNastaliq;
#     }
# </style>
# Out:
# <style>
# p {
#     font-family: IranNastaliq;
#     }
# </style>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=5>
# <div align=center>
#     <font size=30>
#     <p></p>
#     به نام خدا
#     </font>
#     <br>
#     <br>
#     <br><br>
#     <font face="IranNastaliq" size=190 color=blue>
#     طراحی الگوریتم‌ها
#     </font>
#     <br><br>
#     <font face="Niloofar" color=#FF7500>
#     دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#     </font>
#
#     ترم دوم سال تحصیلی ۱۳۹۹-۱۳۹۸
# </div>
#
#
#
# <hr/>
# <font face="Niloofar" color=#ff6600><h3>
# تیم تدریس:<br/></h3>
# </font>
# <div dir="rtl">
#     <p>
#  <font face="XB Niloofar">
# علی شریفی زارچی، کیانوش عباسی، مهدی قربانی، سیده یاسمین طباطبایی، آراد محمدی، مهرداد صابری، امیررضا کاظمی، مهرداد کرابی، امیرحسین قبادی، کیوان شبانی، پارسا اسکندر، محمد صانعیان، کیارش گل‌زاده، علیرضا دقیق، رسول اخوان مهدوی، محمد جوانشاه، محمد مهدوی، اسرا کاشانی‌نیا، محمدکاظم فقیه، مجید گروسی، نیما فتحی، حسن ذاکر، نیما جمالی، آرین میکائیلی، مهدی عرفانیان، حمیدرضا کامکاری، علی پورقاسمی، محمدهادی ستوده
# </font>
#         </p>
# </div>
# <p>سلام و عرض ادب</p>
# <font color=#ff6600><h3>
# کتاب :
# </h3></font>
# <ul>؟؟؟
# <li>Cormen et al., Introduction to algorithms
# <li>Udi Manber, Introduction to algorithms, a creative approach
# </ul>
# <p></p>
#
#
# <font color=#ff6600><h3>
# لینک ثبت‌نام در گروه پیاتزای درس :<br/></h3>
# </font> <a href="piazza.com/sharif/"> piazza.com/sharif/ </a>
# <p></p>
# <font color=#ff6600><h3>
# رمز عبور به کلاس درس در کوئرا :<br/></h3>
# </font> Pass
# <p></p>
# <font color=#ff6600><h3>
# تقویم درس در گوگل :<br/></h3>
# </font> <a href="https://docs.google.com/spreadsheets/d/1Vy6lBuFih2NOVbtJg-5da41FhdFmtWQ227TjF-k-mDA/"> لینک
# </a><p></p>
#
#
# <font color=#ff6600><h3>
# فعالیت‌های درس :
# </h3></font>
# <ul>
# <li>پنج بسته تمرینی
#
# این بخش اصلاح بشه، من نمیدونم چی به چیه =))
# <ul><li>تمرین‌های نظری
#     <li>تمرین‌های عملی (۴ نمره)
#     </ul>
# <li>کوییز تصادفی (۱ نمره)
# <li>چهار کوییز با اعلام قبلی از تمرین‌های نظری (۳ نمره، کوییز با کمترین نمره حذف می‌شود)
# <li>دو آزمون میان‌ترم نظری  (۱.۵ + ۲.۵، آزمون بهتر: ۲.۵)
# <li>دو آزمون میان‌ترم عملی (۳+۱ نمره، آزمون بهتر: ۳)
# <li>آزمون پایان‌ترم (۶ نمره)
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# این درس را بگیرید اگر :
#
# حذف شه بره دیگه؟
# </h3></font>
# <ul>
# <li> علاقه دارید داده‌ساختارها را در عمل یاد بگیرید
# <li> می‌خواهید لذت یادگیری Python را تجربه کنید
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# این درس را حذف کنید اگر :
# </h3></font>
# <ul>
# <li> می‌خواهید تمرین یا امتحان راکُپ بزنید/بدهید
# <li> به نمودار یا نمره‌گرفتن از طریق مذاکره امیدوار هستید
# </ul>
# <p></p>
# <div align=center>
# </div>
# </font>
# </div>

# %%
from IPython.display import HTML
HTML(a)
# Out:
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=5>
# <div align=center>
#     <font size=30>
#     <p></p>
#     به نام خدا
#     </font>
#     <br>
#     <br>
#     <br><br>
#     <font face="IranNastaliq" size=190 color=blue>
#     طراحی الگوریتم‌ها
#     </font>
#     <br><br>
#     <font face="Niloofar" color=#FF7500>
#     دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#     </font>
#
#     ترم دوم سال تحصیلی ۱۳۹۹-۱۳۹۸
# </div>
#
#
#
# <hr/>
# <font face="Niloofar" color=#ff6600><h3>
# تیم تدریس:<br/></h3>
# </font>
# <div dir="rtl">
# <font face="Niloofar">
# علی شریفی زارچی، کیانوش عباسی، مهدی قربانی، سیده یاسمین طباطبایی، آراد محمدی، مهرداد صابری، امیررضا کاظمی، مهرداد کرابی، امیرحسین قبادی، کیوان شبانی، پارسا اسکندر، محمد صانعیان، کیارش گل‌زاده، علیرضا دقیق، رسول اخوان مهدوی، محمد جوانشاه، محمد مهدوی، اسرا کاشانی‌نیا، محمدکاظم فقیه، مجید گروسی، نیما فتحی، حسن ذاکر، نیما جمالی، آرین میکائیلی، مهدی عرفانیان، حمیدرضا کامکاری، علی پورقاسمی، محمدهادی ستوده
# ...

# %%
}
