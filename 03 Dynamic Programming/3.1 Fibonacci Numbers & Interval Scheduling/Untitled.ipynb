# %%
int Fib(int n) {
    if (n > 2) return Fib(n-1) + Fib(n-2);
    else return 1;
}

# %%
def Fib(n):
    if n > 2:
        return Fib(n-1)+Fib(n-2)
    return 1

# %%
Fib(40)
# Out:
# 102334155

# %%
f = [0] * 100000
f[1] = 1
f[2] = 1
for i in range(3, 100000):
    f[i] = f[i-1] + f[i-2]

# %%
f[99999]
# Out:
# ...
