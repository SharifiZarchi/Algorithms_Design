# %%
import os
import subprocess
from pathlib import Path
import numpy as np
import operator
import json
import math
import resource

# %%
DIVISIONS = ['div1', 'div2', 'all']

DIV_THRESHOLD = 1500

# %%
division = 'all'

# %%
time_limit = 10
memory_limit = 256 * 1024 * 1024

# %%
all_students = ['94101737', '94101975', '95105657', '95106494', '95108008', '95109242', '95109383', '96101262', '96101913', '96104881', '96105553', '96105575', '96105626', '96105637', '96105672', '96105683', '96105712', '96105807', '96105829', '96105853', '96105864', '96105875', '96105886', '96105948', '96105983', '96106033', '96106077', '96106117', '96109588', '96109599', '96109606', '96109663', '96109714', '96109736', '96109747', '96109758', '96109899', '96109906', '96110067', '96110129', '96110797', '97100581', '97102044', '97102441', '97105696', '97105771', '97105844', '97105855', '97106262', '97106295', '97106419', '97110155', '97110206', '97213093', '98209048']

# %%
import shutil

working_directory = os.path.abspath('')
os.chdir(working_directory)

submissions_path = Path(os.path.join(working_directory, 'submissions'))

tests_path = Path(os.path.join(working_directory, 'tests'))

executables_path = os.path.join(working_directory, 'executables')

rating_file = 'rating.json'

if os.path.exists(executables_path):
    shutil.rmtree(executables_path)

os.mkdir(executables_path)
    
outputs_path = Path(os.path.join(working_directory, 'outputs'))
    
if os.path.exists(outputs_path):
    shutil.rmtree(outputs_path)    
    
os.mkdir(outputs_path)

# %%
students = list(os.walk(submissions_path))[0][1]

if division != 'div1':
    students += ['dummy']

try:
    with open(rating_file, 'r', encoding='utf-8') as fp:
        rate = json.load(fp)

    for student in students:
        if student not in rate:
            print(f'FATAL ERROR: {student} has no rating!')

    for std in rate:
        if std not in students:
            print(f'{std} did not submit at this round.')
            students.append(std)
except FileNotFoundError:
    print('No rating file.')

if division == 'div1':
    students = list(filter(lambda x: rate[x] >= DIV_THRESHOLD, students))
elif division == 'div2':
    students = list(filter(lambda x: rate[x] < DIV_THRESHOLD, students))
            
final_results = {student: {'ranking': None, 'tests': {}, 'final_score': 0, 'prev_rating': 0, 'new_rating': 0} for student in students}
# Out:
# No rating file.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-50cab19764a7> in <module>
#      22     students = list(filter(lambda x: rate[x] >= DIV_THRESHOLD, students))
#      23 elif division == 'div2':
# ---> 24     students = list(filter(lambda x: rate[x] < DIV_THRESHOLD, students))
#      25
#      26 final_results = {student: {'ranking': None, 'tests': {}, 'final_score': 0, 'prev_rating': 0, 'new_rating': 0} for student in students}
#
# <ipython-input-7-50cab19764a7> in <lambda>(x)
#      22     students = list(filter(lambda x: rate[x] >= DIV_THRESHOLD, students))
#      23 elif division == 'div2':
# ---> 24     students = list(filter(lambda x: rate[x] < DIV_THRESHOLD, students))
#      25
#      26 final_results = {student: {'ranking': None, 'tests': {}, 'final_score': 0, 'prev_rating': 0, 'new_rating': 0} for student in students}
#
# NameError: name 'rate' is not defined

# %%
print(division, 'contest')
print(f'{len(students)} students we have: {students}')
# Out:
# all contest
# 40 students we have: ['97100581', '97102044', '97106419', '96109599', '94101737', '96105875', '97105771', '96105886', '96110797', '96105829', '96109606', '96109663', '96110129', '97106262', '96105712', '97105844', '96105948', '96105983', '96109736', '96105553', '97102441', '94170733', '96109906', '97105855', '97105696', '98209048', '96105683', '97110206', '95109383', '95108008', '96101262', '96106077', '96105807', '96110067', '97106295', '96109588', '97110155', '96109747', '96109714', 'dummy']

# %%
print(submissions_path)
print(working_directory)
print(tests_path)
print(executables_path)
# Out:
# /Users/kianooshabbasi/Dropbox/DA99/Covid Challenge/Round-1/judge/submissions
# /Users/kianooshabbasi/Dropbox/DA99/Covid Challenge/Round-1/judge
# /Users/kianooshabbasi/Dropbox/DA99/Covid Challenge/Round-1/judge/tests
# /Users/kianooshabbasi/Dropbox/DA99/Covid Challenge/Round-1/judge/executables

# %%
all_tests = list(map(lambda path: os.path.basename(path).split('in')[1].split('.txt')[0], tests_path.rglob('*.txt')))

# %%
print('Compiling codes...')

errors = 0

for student in students:
    cpp_files = list(Path(os.path.join(submissions_path, student)).rglob('*.c*'))
    ans = [] 
    for i in cpp_files:
        if i.name.endswith(".cxx") or i.name.endswith(".cpp"):
            ans.append(i)
    cpp_files = ans
    
    if len(cpp_files) != 1:
        print(f'Something wrong with {student}\'s files. Could not find the cpp file')
        final_results[student]['tests'] = {test: {'score': 0, 'cost': None, 'status': 'No Submission'} for test in all_tests}
        errors += 1
        continue

    cpp_file = cpp_files[0]
    output_file = os.path.join(submissions_path, student, 'output-runnable')
    
    process = subprocess.run(['g++', cpp_file, '-w', '-DONLINE_JUDGE', 
                              '-std=c++14', '-fno-asm', '-Dasm=error', '-lm',
                              '-O2', '-o', output_file], capture_output=True)
    if process.returncode:
        print(f'Could not compile {student}\'s code.')
        print(f'*******************')
        print(process.stderr.decode()[:300])
        print(f'*******************')              
        final_results[student]['tests'] = {test: {'score': 0, 'cost': None, 'status': 'Compiler Error'} for test in all_tests}
        errors += 1
        continue
    
    
    shutil.move(output_file, os.path.join(executables_path, f'{student}.exec'))

print(f'Compilation finished for {len(students)} codes: {errors} error(s).')
print('\n=================================================\n')
# Out:
# Compiling codes...
# Something wrong with dummy's files. Could not find the cpp file
# Compilation finished for 40 codes: 1 error(s).
#
# =================================================

# %%
print('Executing codes...')

def limit_virtual_memory():
    resource.setrlimit(resource.RLIMIT_AS, (memory_limit, memory_limit))


for executable in list(Path(executables_path).rglob('*.exec')):    
    student_id = os.path.basename(executable).split('.exec')[0]
        
    print(f'Running {student_id}\'s codes')        
        
    for test_file in tests_path.rglob('*.txt'):
        test_name = os.path.basename(test_file).split('.txt')[0]
        
        test_num = test_name[2:]
        
        output_dir = os.path.join(outputs_path, test_name)
        os.makedirs(output_dir, exist_ok=True)
        
        output_path = os.path.join(output_dir, f'output-{student_id}.txt')
        
        input_file = open(test_file)
        output_file = open(output_path, 'w')
        
        try:
            subprocess.run([executable], stdin=input_file, stdout=output_file, timeout=time_limit, preexec_fn=limit_virtual_memory, check=True)
            output_file.close()
        except subprocess.TimeoutExpired:
            print(f'Time limit exceeded on test {test_name}')
            final_results[student_id]['tests'][test_num] = {'score': 0, 'cost': None, 'status': 'Time limit'}
            os.remove(output_path)
        except subprocess.CalledProcessError:
            print(f'Runtime error on test {test_name}')
            final_results[student_id]['tests'][test_num] = {'score': 0, 'cost': None, 'status': 'Runtime Error'}
            os.remove(output_path)
        
        input_file.close()
        
print('\n=================================================\n')
# Out:
# Executing codes...
# Running 97105696's codes
# Running 97110206's codes
# Running 96109599's codes
# Running 96109736's codes
# Running 97106262's codes
# Running 97105771's codes
# Running 96101262's codes
# Running 97110155's codes
# Running 96105807's codes
# Running 97105855's codes
# Time limit exceeded on test input20
# Time limit exceeded on test input15
# Time limit exceeded on test input14
# Running 96109747's codes
# Running 97106419's codes
# Running 98209048's codes
# Running 96105683's codes
# Runtime error on test input17
# Running 96105553's codes
# Running 97105844's codes
# Running 94101737's codes
# Time limit exceeded on test input19
# Time limit exceeded on test input18
# Time limit exceeded on test input3
# Time limit exceeded on test input7
# Time limit exceeded on test input6
# Time limit exceeded on test input20
# Time limit exceeded on test input5
# Time limit exceeded on test input8
# Time limit exceeded on test input10
# Time limit exceeded on test input11
# Runtime error on test input9
# Time limit exceeded on test input13
# Time limit exceeded on test input12
# Time limit exceeded on test input16
# Time limit exceeded on test input17
# Runtime error on test input15
# Time limit exceeded on test input14
# Running 96109663's codes
# Running 96105712's codes
# Running 97100581's codes
# Running 96109588's codes
# Time limit exceeded on test input14
# Running 97102441's codes
# Running 96109906's codes
# Time limit exceeded on test input19
# Time limit exceeded on test input18
# Time limit exceeded on test input3
# Time limit exceeded on test input7
# Time limit exceeded on test input6
# Time limit exceeded on test input20
# Time limit exceeded on test input10
# Time limit exceeded on test input11
# Time limit exceeded on test input15
# Time limit exceeded on test input14
# Running 96106077's codes
# Running 96105948's codes
# Time limit exceeded on test input6
# Time limit exceeded on test input20
# Time limit exceeded on test input15
# Running 95108008's codes
# Running 96105875's codes
# Time limit exceeded on test input18
# Running 96110067's codes
# Time limit exceeded on test input19
# Time limit exceeded on test input6
# Time limit exceeded on test input20
# Time limit exceeded on test input15
# Running 94170733's codes
# Time limit exceeded on test input20
# Runtime error on test input17
# Running 97102044's codes
# Time limit exceeded on test input19
# Time limit exceeded on test input18
# Time limit exceeded on test input16
# Time limit exceeded on test input17
# Running 95109383's codes
# Running 96105886's codes
# Running 97106295's codes
# Running 96109606's codes
# Running 96109714's codes
# Runtime error on test input6
# Runtime error on test input11
# Runtime error on test input12
# Running 96110129's codes
# Time limit exceeded on test input1
# Runtime error on test input19
# Runtime error on test input18
# Time limit exceeded on test input2
# Time limit exceeded on test input3
# Runtime error on test input7
# Runtime error on test input6
# Runtime error on test input4
# Time limit exceeded on test input20
# Runtime error on test input5
# Time limit exceeded on test input8
# Runtime error on test input10
# Runtime error on test input11
# Time limit exceeded on test input9
# Runtime error on test input13
# Runtime error on test input12
# Runtime error on test input16
# Runtime error on test input17
# Time limit exceeded on test input15
# Runtime error on test input14
# Running 96105983's codes
# Runtime error on test input1
# Runtime error on test input19
# Runtime error on test input18
# Runtime error on test input2
# Runtime error on test input3
# Runtime error on test input7
# Runtime error on test input6
# Runtime error on test input4
# Runtime error on test input20
# Runtime error on test input5
# Runtime error on test input8
# Runtime error on test input10
# Runtime error on test input11
# Runtime error on test input9
# Runtime error on test input13
# Runtime error on test input12
# Runtime error on test input16
# Runtime error on test input17
# Runtime error on test input15
# Runtime error on test input14
# Running 96105829's codes
# Running 96110797's codes
#
# =================================================

# %%
checker_files = list(Path(working_directory).rglob('checker.cpp')) 
if len(checker_files) != 1:
    print("Please provide one checker.cpp file")

judge = os.path.join(working_directory, 'judge.exec')    

process = subprocess.run(['g++', checker_files[0], '-std=c++14', '-O2', '-o', judge], capture_output=True)
if process.returncode:
    print(f'Could not compile {student}\'s code:')
    print(process.stderr.decode()[:300])

# %%
cost = {}
for s in students:
    cost[s] = {}

for test in list(Path(outputs_path).rglob('in*')):
    this_test = os.path.basename(test) 
    test_num = this_test[2:]
    
    input_file = os.path.join(tests_path, this_test + '.txt')
    
    valid_submissions = list(test.rglob('output*.txt'))
    print("Seeing submissions output for test ", test_num, "\n")

    for student_output in valid_submissions:
        student_id = student_output.name.split('output-')[1].split('.txt')[0]
        
        try:
            out_path = os.path.join(test, f'checker-{student_id}.txt')
            log_path = os.path.join(test, f'log-{student_id}.txt')
            out_file = open(out_path, 'w')
            log_file = open(log_path, 'w')
            
            subprocess.run([judge, input_file, student_output], timeout=2, stdout=out_file, stderr=log_file, check=True)
            
            with open(out_path, "r") as f:
                checker_out = f.read()
            
            out_file.close()
            log_file.close()
            
            cost[student_id][test_num] = int(checker_out)
            print(f"{student_id}'s cost is {checker_out}")
        except subprocess.TimeoutExpired:
            print(f'Time limit exceeded on checker. its not normal')
            os.remove(log_file)
        except subprocess.CalledProcessError:
            print(f'Runtime error on checker. its not normal')
            os.remove(log_file)
# Out:
# Seeing submissions output for test  put16
#
# 96109736's cost is 27377347445
#
# 96105683's cost is 14706630352
#
# 96110067's cost is 9964867226
#
# 97106262's cost is 10963997389
#
# 97110206's cost is 11752724826
#
# 96109906's cost is -1
#
# 96105875's cost is 11944867034
#
# 95108008's cost is 10963997389
#
# 96105807's cost is 19713650579
#
# 96106077's cost is 11298474936
#
# 97105696's cost is 11798950837
#
# 96105829's cost is 10081550648
#
# 96105948's cost is 23714388558
#
# 96109747's cost is 15257624399
#
# 96105553's cost is 16690363065
#
# 96110797's cost is 16690363065
#
# 96109588's cost is 2136354063596
#
# 97106419's cost is 19149120776
#
# 97102441's cost is 14436807728
#
# 97105844's cost is 10213472960
#
# 98209048's cost is 12900870450
#
# 96101262's cost is 21224404412
#
# 96109606's cost is 11766719899
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 10028010874
#
# 96105886's cost is 16690363065
#
# 96109663's cost is 10587661565
#
# 94170733's cost is 10554162157
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 30582080335
#
# 97100581's cost is 11326339328
#
# 96105712's cost is 11632484011
#
# 97105771's cost is 11135976968
#
# Seeing submissions output for test  put11
#
# 96109736's cost is 47690920824
#
# 96105683's cost is 42301065939
#
# 96110067's cost is 32281327071
#
# 97106262's cost is 50042292174
#
# 97110206's cost is 25785513617
#
# 96105875's cost is 40802278668
#
# 95108008's cost is 23409213886
#
# 96105807's cost is 66373080185
#
# 96106077's cost is 33166630746
#
# 97105696's cost is 33978228924
#
# 96105829's cost is 58365129139
#
# 96105948's cost is -1
#
# 96109747's cost is 53581582044
#
# 96105553's cost is 54349190396
#
# 96110797's cost is 59948352688
#
# 96109588's cost is 844999802336
#
# 97106419's cost is 63404208420
#
# 97102441's cost is 24539560888
#
# 97105844's cost is 14913036207
#
# 97102044's cost is 24804426676
#
# 98209048's cost is 125067227088
#
# 96101262's cost is 66687966154
#
# 96109606's cost is 17334173441
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 17277449850
#
# 96105886's cost is 59342969682
#
# 96109663's cost is 22154149770
#
# 94170733's cost is 33978228974
#
# 97106295's cost is -1
#
# 97110155's cost is 101014109469
#
# 97100581's cost is 16344138532
#
# 96105712's cost is 29965613587
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put18
#
# 96109736's cost is 111304705788
#
# 96105683's cost is 65152623615
#
# 96110067's cost is 43664787175
#
# 97106262's cost is 105528925663
#
# 97110206's cost is 34741329573
#
# 95108008's cost is 36490118838
#
# 96105807's cost is 113108067394
#
# 96106077's cost is 68290531168
#
# 97105696's cost is 66973759212
#
# 96105829's cost is 117610041410
#
# 96105948's cost is -1
#
# 96109747's cost is 116014598360
#
# 96105553's cost is 92028197344
#
# 96110797's cost is 91140555460
#
# 96109588's cost is 238864540413
#
# 97106419's cost is 99421621066
#
# 97102441's cost is 66672860033
#
# 97105844's cost is 31582288775
#
# 98209048's cost is 99523411946
#
# 96101262's cost is 141431796552
#
# 96109606's cost is 48896576417
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 40910669604
#
# 96105886's cost is 92028197344
#
# 96109663's cost is 44042462477
#
# 94170733's cost is -1
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 155339707460
#
# 97100581's cost is 46042857060
#
# 96105712's cost is 65958792485
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put20
#
# 96109736's cost is 0
#
# 96105683's cost is 0
#
# 97106262's cost is 0
#
# 97110206's cost is 0
#
# 96105875's cost is 0
#
# 95108008's cost is 4
#
# 96105807's cost is 28
#
# 96106077's cost is 0
#
# 97105696's cost is 0
#
# 96105829's cost is 0
#
# 96109747's cost is 0
#
# 96105553's cost is 0
#
# 96110797's cost is 0
#
# 96109588's cost is 12
#
# 97106419's cost is 39
#
# 97102441's cost is 0
#
# 97105844's cost is -1
#
# 97102044's cost is 0
#
# 98209048's cost is 37
#
# 96101262's cost is 42
#
# 96109606's cost is 0
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 96105886's cost is 0
#
# 96109663's cost is 0
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 28
#
# 97100581's cost is 0
#
# 96105712's cost is 0
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put19
#
# 96109736's cost is 127216860456
#
# 96105683's cost is 68135919606
#
# 97106262's cost is 64251134291
#
# 97110206's cost is 43509135224
#
# 96105875's cost is 79819770088
#
# 95108008's cost is 36760962841
#
# 96105807's cost is 108758547342
#
# 96106077's cost is 58180734209
#
# 97105696's cost is 54034969352
#
# 96105829's cost is 76321031533
#
# 96105948's cost is -1
#
# 96109747's cost is 82318714975
#
# 96105553's cost is 73432771699
#
# 96110797's cost is 94127405302
#
# 96109588's cost is 176128404466
#
# 97106419's cost is 122196632774
#
# 97102441's cost is 63806858259
#
# 97105844's cost is 30038292815
#
# 98209048's cost is 98672596965
#
# 96101262's cost is 138426107557
#
# 96109606's cost is 38746073774
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 33901402013
#
# 96105886's cost is 94038729498
#
# 96109663's cost is 43028514397
#
# 94170733's cost is 48196524359
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 154016423572
#
# 97100581's cost is 34471165546
#
# 96105712's cost is 58310785198
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put10
#
# 96109736's cost is 32326386031
#
# 96105683's cost is 23694245784
#
# 96110067's cost is 22518247440
#
# 97106262's cost is 30591853902
#
# 97110206's cost is 15119846135
#
# 96105875's cost is 14174830303
#
# 95108008's cost is 11693802942
#
# 96105807's cost is 38709580404
#
# 96106077's cost is 12451333694
#
# 97105696's cost is 19323659049
#
# 96105829's cost is 35316441361
#
# 96105948's cost is -1
#
# 96109747's cost is 42946737523
#
# 96105553's cost is 31466037479
#
# 96110797's cost is 34371464094
#
# 96109588's cost is 668191022846
#
# 97106419's cost is 37252454526
#
# 97102441's cost is 25372139866
#
# 97105844's cost is 8273733631
#
# 97102044's cost is 19418355590
#
# 98209048's cost is 36064518077
#
# 96101262's cost is 42573704691
#
# 96109606's cost is 9875620530
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 9052530697
#
# 96105886's cost is 31466037479
#
# 96109663's cost is 21166184296
#
# 94170733's cost is 16725348623
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 58411159881
#
# 97100581's cost is 8126830437
#
# 96105712's cost is 23482370854
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put17
#
# 96109736's cost is 87820057219
#
# 96110067's cost is 38904666479
#
# 97106262's cost is 51005825098
#
# 97110206's cost is 35348990841
#
# 96109906's cost is -1
#
# 96105875's cost is 62179166063
#
# 95108008's cost is 34919306494
#
# 96105807's cost is 63482343918
#
# 96106077's cost is 36687693724
#
# 97105696's cost is 39092748065
#
# 96105829's cost is 30270703368
#
# 96105948's cost is 52411168406
#
# 96109747's cost is 50308513321
#
# 96105553's cost is 57361573525
#
# 96110797's cost is 58223717393
#
# 96109588's cost is 3866792478753
#
# 97106419's cost is 57361573525
#
# 97102441's cost is 46593605581
#
# 97105844's cost is 26937402650
#
# 98209048's cost is -1
#
# 96101262's cost is 63482343918
#
# 96109606's cost is 32155814663
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 44835520056
#
# 96105886's cost is 57361573525
#
# 96109663's cost is 31552852729
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 88905337626
#
# 97100581's cost is 30632067812
#
# 96105712's cost is 39016320003
#
# 97105771's cost is 35150905610
#
# Seeing submissions output for test  put3
#
# 96109736's cost is 22276555
#
# 96105683's cost is 27940576
#
# 96110067's cost is 17210131
#
# 97106262's cost is 49878964
#
# 97110206's cost is 27909106
#
# 96105875's cost is 12474824
#
# 95108008's cost is 13378755
#
# 96105807's cost is 44629188
#
# 96106077's cost is 16354383
#
# 97105696's cost is 21442035
#
# 96105829's cost is 55556565
#
# 96105948's cost is -1
#
# 96109747's cost is 56921673
#
# 96105553's cost is 40116699
#
# 96110797's cost is 40116699
#
# 96109588's cost is 9359554
#
# 97106419's cost is 41635410
#
# 97102441's cost is 18176153
#
# 97105844's cost is 9148157
#
# 97102044's cost is 24948700
#
# 98209048's cost is 52482059
#
# 96101262's cost is 53679213
#
# 96109606's cost is 11409331
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 8998485
#
# 96105886's cost is 40116699
#
# 96109663's cost is 20781131
#
# 94170733's cost is 21637031
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 65834890
#
# 97100581's cost is 10475876
#
# 96105712's cost is 21721911
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put4
#
# 96109736's cost is 10763295883
# 96105683's cost is 11965566492
#
# 96110067's cost is 6952592999
#
# 97106262's cost is 11406609188
#
# 97110206's cost is 10737796328
#
# 96109906's cost is -1
#
# 96105875's cost is 12363669109
#
# 95108008's cost is 9221779084
#
# 96105807's cost is 15217312093
#
# 96106077's cost is 7595906305
#
# 97105696's cost is 8045008030
#
# 96105829's cost is 7595906284
#
# 96105948's cost is 13153839346
#
# 96109747's cost is 10569084350
#
# 96105553's cost is 12948125987
#
# 96110797's cost is 12948125987
#
# 96109588's cost is 19304101370368
#
# 97106419's cost is 12948125987
#
# 97102441's cost is 8045008032
#
# 97105844's cost is 7036949002
#
# 97102044's cost is 10229838136
#
# 98209048's cost is 11355610120
#
# 96101262's cost is 15217312093
#
# 96109606's cost is 8966888848
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 6952593001
#
# 96105886's cost is 12948125987
#
# 96109663's cost is 8688321336
#
# 94170733's cost is 8045008030
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 94101737's cost is -1
#
# 97110155's cost is 21771802405
#
# 97100581's cost is 6952592999
#
# 96105712's cost is 7595906305
#
# 97105771's cost is 7595906305
#
# Seeing submissions output for test  put5
#
# 96109736's cost is 8679922533
#
# 96105683's cost is 1143418385
#
# 96110067's cost is 1143267205
#
# 97106262's cost is 1828691104
#
# 97110206's cost is 1142998723
#
# 96109906's cost is -1
#
# 96105875's cost is 2969825693
#
# 95108008's cost is 1599451225
#
# 96105807's cost is 5178025938
#
# 96106077's cost is 1142742708
#
# 97105696's cost is 2056479901
#
# 96105829's cost is 1370808733
#
# 96105948's cost is 5255949494
#
# 96109747's cost is 2513928178
#
# 96105553's cost is 1600603585
#
# 96110797's cost is 1829011098
#
# 96109588's cost is 3273588981
#
# 97106419's cost is 7004943561
#
# 97102441's cost is 1371192556
#
# 97105844's cost is 1142834349
#
# 97102044's cost is 1143111698
#
# 98209048's cost is 8602709634
#
# 96101262's cost is 5787057084
#
# 96109606's cost is 2056010017
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 2056805743
#
# 96105886's cost is 1600603585
#
# 96109663's cost is 1371249609
#
# 94170733's cost is 2056437377
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 5635972026
#
# 97100581's cost is 1142722486
#
# 96105712's cost is 1143105057
#
# 97105771's cost is 4263093722
#
# Seeing submissions output for test  put2
#
# 96109736's cost is 2000300020
#
# 96105683's cost is 4000300040
#
# 96110067's cost is 2000300020
#
# 97106262's cost is 2000300020
#
# 97110206's cost is 2000300020
#
# 96109906's cost is -1
#
# 96105875's cost is 2000300020
#
# 95108008's cost is 2000300020
#
# 96105807's cost is 4000400040
#
# 96106077's cost is 2000300020
#
# 97105696's cost is 2000300020
#
# 96105829's cost is 2000300020
#
# 96105948's cost is 2000300040
#
# 96109747's cost is 2000300020
#
# 96105553's cost is 3000300030
#
# 96110797's cost is 3000300030
#
# 96109588's cost is 2000300020
#
# 97106419's cost is 3000300030
#
# 97102441's cost is 2000300040
#
# 97105844's cost is 2000300020
#
# 97102044's cost is 2000300020
#
# 98209048's cost is 3000300030
#
# 96101262's cost is 4000400040
#
# 96109606's cost is 2000300020
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 2000300020
#
# 96105886's cost is 3000300030
#
# 96109663's cost is 2000300020
#
# 94170733's cost is 2000300020
#
# 97106295's cost is 4000400040
#
# 96109714's cost is -1
#
# 94101737's cost is -1
#
# 97110155's cost is 6000400060
#
# 97100581's cost is 2000300020
#
# 96105712's cost is 2000300020
#
# 97105771's cost is 2000300020
#
# Seeing submissions output for test  put12
#
# 96109736's cost is 624652968
#
# 96105683's cost is 694061724
#
# 96110067's cost is 416452410
#
# 97106262's cost is 624652968
#
# 97110206's cost is 694010409
#
# 96109906's cost is -1
#
# 96105875's cost is 416452410
#
# 95108008's cost is 555244233
#
# 96105807's cost is 971645370
#
# 96106077's cost is 416452431
#
# 97105696's cost is 624601695
#
# 96105829's cost is 347069322
#
# 96105948's cost is 763367892
#
# 96109747's cost is 624678615
#
# 96105553's cost is 763470438
#
# 96110797's cost is 763470438
#
# 96109588's cost is 347043696
#
# 97106419's cost is 763470438
#
# 97102441's cost is 555346758
#
# 97105844's cost is 416401158
#
# 97102044's cost is 555269880
#
# 98209048's cost is 1249254726
#
# 96101262's cost is 971645370
#
# 96109606's cost is 555321132
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 416401179
#
# 96105886's cost is 763470438
#
# 96109663's cost is 485835498
#
# 94170733's cost is 624601695
#
# 97106295's cost is -1
#
# 97110155's cost is 1388097780
#
# 97100581's cost is 485835519
#
# 96105712's cost is 485861166
#
# 97105771's cost is 763342245
#
# Seeing submissions output for test  put15
#
# 96109736's cost is 63
#
# 96105683's cost is 54
#
# 97106262's cost is 86
#
# 97110206's cost is 54
#
# 96105875's cost is 59
#
# 95108008's cost is 63
#
# 96105807's cost is 257320
#
# 96106077's cost is 56
#
# 97105696's cost is 79
#
# 96105829's cost is 90
#
# 96109747's cost is 101
#
# 96105553's cost is 61
#
# 96110797's cost is 63
#
# 96109588's cost is 85
#
# 97106419's cost is 324241
#
# 97102441's cost is 84
#
# 97105844's cost is -1
#
# 97102044's cost is 58
#
# 98209048's cost is 658308
#
# 96101262's cost is 210636
#
# 96109606's cost is 79
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 96105886's cost is 65
#
# 96109663's cost is 55
#
# 94170733's cost is 79
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 227454
#
# 97100581's cost is 50
#
# 96105712's cost is 59
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put14
#
# 96109736's cost is 11577971471
#
# 96105683's cost is 3145864299
#
# 96110067's cost is -1
#
# 97106262's cost is 5242810737
#
# 97110206's cost is 5766968100
#
# 96105875's cost is 6291537968
#
# 95108008's cost is 4718558223
#
# 96105807's cost is 10116038144
#
# 96106077's cost is 3145800785
#
# 97105696's cost is 5767126677
#
# 96105829's cost is 5242842470
#
# 96105948's cost is -1
#
# 96109747's cost is 6815695303
#
# 96105553's cost is 5242810737
#
# 96110797's cost is 4718558223
#
# 97106419's cost is 5205890482
#
# 97102441's cost is 4718653534
#
# 97105844's cost is 5206176447
#
# 97102044's cost is 4194369247
#
# 98209048's cost is 23562541670
#
# 96101262's cost is 10603211762
#
# 96109606's cost is 5767126673
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 96105886's cost is 4718589956
#
# 96109663's cost is 3145864283
#
# 94170733's cost is 5767126677
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 6217506988
#
# 97100581's cost is 3145800697
#
# 96105712's cost is 3145864203
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put13
#
# 96109736's cost is 1374505249
#
# 96105683's cost is 1370425938
#
# 96110067's cost is 1370573732
#
# 97106262's cost is 1570704791
#
# 97110206's cost is 1059711002
#
# 96109906's cost is -1
#
# 96105875's cost is 3259339214
#
# 95108008's cost is 1452183983
#
# 96105807's cost is 2824776396
#
# 96106077's cost is 1059563208
#
# 97105696's cost is 1534089822
#
# 96105829's cost is 1177584400
#
# 96105948's cost is 1567142759
#
# 96109747's cost is 2237351636
#
# 96105553's cost is 1374505249
#
# 96110797's cost is 1374431352
#
# 96109588's cost is 2315299118
#
# 97106419's cost is 1492378647
#
# 97102441's cost is 1333663175
#
# 97105844's cost is 1374653043
#
# 97102044's cost is 1533942028
#
# 98209048's cost is 7069552939
#
# 96101262's cost is 3253216936
#
# 96109606's cost is 1534089822
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 1375170322
#
# 96105886's cost is 1374505249
#
# 96109663's cost is 1059711002
#
# 94170733's cost is 1533794234
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 1806673278
#
# 97100581's cost is 1059563208
#
# 96105712's cost is 1059563208
#
# 97105771's cost is 3604126536
#
# Seeing submissions output for test  put7
#
# 96109736's cost is 36448220394
#
# 96105683's cost is 33009136442
#
# 96110067's cost is 11655829040
#
# 97106262's cost is 51494307847
#
# 97110206's cost is 17850127027
#
# 96105875's cost is 32235583346
#
# 95108008's cost is 15844633697
#
# 96105807's cost is 53715736956
#
# 96106077's cost is 20900774915
#
# 97105696's cost is 24223579904
#
# 96105829's cost is 59416315315
#
# 96105948's cost is -1
#
# 96109747's cost is 42161877272
#
# 96105553's cost is 47532981130
#
# 96110797's cost is 47532981130
#
# 96109588's cost is 599373100092
#
# 97106419's cost is 53665144643
#
# 97102441's cost is 45797431620
#
# 97105844's cost is 10563379083
#
# 97102044's cost is 21173761550
#
# 98209048's cost is 81648940470
#
# 96101262's cost is 49348971677
#
# 96109606's cost is 13205758458
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 10564597089
#
# 96105886's cost is 47533002743
#
# 96109663's cost is 17074673372
#
# 94170733's cost is 24222884564
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 79348423486
#
# 97100581's cost is 10564135670
#
# 96105712's cost is 26819079233
#
# 97105771's cost is -1
#
# Seeing submissions output for test  put9
#
# 96109736's cost is 18465527904
#
# 96105683's cost is 7775482268
#
# 96110067's cost is 2916405607
#
# 97106262's cost is 8261933666
#
# 97110206's cost is 4859698019
#
# 96109906's cost is -1
#
# 96105875's cost is 9718529937
#
# 95108008's cost is 4373826907
#
# 96105807's cost is 14253632005
#
# 96106077's cost is 4374626713
#
# 97105696's cost is 9232712764
#
# 96105829's cost is 2916100965
#
# 96105948's cost is 11213060036
#
# 96109747's cost is 10691164783
#
# 96105553's cost is 11176590366
#
# 96110797's cost is 10690749086
#
# 96109588's cost is 5466512341
# 97106419's cost is 15670684378
#
# 97102441's cost is 13605499463
#
# 97105844's cost is 2915996738
#
# 97102044's cost is 2915935952
#
# 98209048's cost is 7370172268
#
# 96101262's cost is 17534535341
#
# 96109606's cost is 7774796702
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 2916357375
#
# 96105886's cost is 11176590366
#
# 96109663's cost is 4859481305
#
# 94170733's cost is 6803247568
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 19032582120
#
# 97100581's cost is 5347024895
#
# 96105712's cost is -1
#
# 97105771's cost is 8663150194
#
# Seeing submissions output for test  put8
#
# 96109736's cost is 551060
#
# 96105683's cost is 641616
#
# 96110067's cost is 373943
#
# 97106262's cost is 551060
#
# 97110206's cost is 523516
#
# 96109906's cost is -1
#
# 96105875's cost is 464461
#
# 95108008's cost is 492022
#
# 96105807's cost is 150542682
#
# 96106077's cost is 373970
#
# 97105696's cost is 547092
#
# 96105829's cost is 75180863
#
# 96105948's cost is 599116400
#
# 96109747's cost is 751758
#
# 96105553's cost is 669146
#
# 96110797's cost is 728194
#
# 96109588's cost is 373971
#
# 97106419's cost is 300038367
#
# 97102441's cost is 759642
#
# 97105844's cost is 373945
#
# 97102044's cost is 637643
#
# 98209048's cost is 224967823
#
# 96101262's cost is 75735801
#
# 96109606's cost is 547095
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 429039
#
# 96105886's cost is 669146
#
# 96109663's cost is 464487
#
# 94170733's cost is 547092
#
# 97106295's cost is -1
#
# 96109714's cost is -1
#
# 97110155's cost is 450238649
#
# 97100581's cost is 373988
#
# 96105712's cost is 464475
#
# 97105771's cost is 300179983
#
# Seeing submissions output for test  put1
#
# 96109736's cost is 5000002
#
# 96105683's cost is 7000004
#
# 96110067's cost is 5000002
#
# 97106262's cost is 5000002
#
# 97110206's cost is 5000002
#
# 96109906's cost is -1
#
# 96105875's cost is 5000002
#
# 95108008's cost is 5000002
#
# 96105807's cost is 8000004
#
# 96106077's cost is 5000002
#
# 97105696's cost is 5000002
#
# 96105829's cost is 5000002
#
# 96105948's cost is 5000002
#
# 96109747's cost is 5000002
#
# 96105553's cost is 6000003
#
# 96110797's cost is 6000003
#
# 96109588's cost is 5000002
#
# 97106419's cost is 6000003
#
# 97102441's cost is 5000004
#
# 97105844's cost is 5000002
#
# 97102044's cost is 5000002
#
# 98209048's cost is 6000005
#
# 96101262's cost is 8000004
#
# 96109606's cost is 5000002
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 5000002
#
# 96105886's cost is 6000003
#
# 96109663's cost is 5000002
#
# 94170733's cost is 5000002
#
# 97106295's cost is 8000004
#
# 96109714's cost is -1
#
# 94101737's cost is -1
#
# 97110155's cost is 10000006
#
# 97100581's cost is 5000002
#
# 96105712's cost is 5000002
#
# 97105771's cost is 5000002
#
# Seeing submissions output for test  put6
#
# 96109736's cost is 40408874455
#
# 96105683's cost is 29477849700
#
# 97106262's cost is 48520385208
#
# 97110206's cost is 21233081080
#
# 96105875's cost is 20110146839
#
# 95108008's cost is 15858233008
#
# 96105807's cost is 53702847450
#
# 96106077's cost is 20199271606
#
# 97105696's cost is 23124477691
#
# 96105829's cost is 54003125650
#
# 96109747's cost is 42767724757
#
# 96105553's cost is 41471855725
#
# 96110797's cost is 41078595554
#
# 96109588's cost is 203544402659
#
# 97106419's cost is 46849877132
#
# 97102441's cost is 37507577362
#
# 97105844's cost is 11593734913
#
# 97102044's cost is 22175623010
#
# 98209048's cost is 45033044973
#
# 96101262's cost is 59989514754
#
# 96109606's cost is 18124709237
#
# 96109599's cost is -1
#
# 95109383's cost is -1
#
# 97105855's cost is 24433055974
#
# 96105886's cost is 41471855725
#
# 96109663's cost is 19132059017
#
# 94170733's cost is 19917174649
#
# 97106295's cost is -1
#
# 97110155's cost is 75764422488
#
# 97100581's cost is 15310216077
#
# 96105712's cost is 23519545478
#
# 97105771's cost is -1

# %%
def prob(ri, rj):
    delta = (rj - ri) / 400.
    return 1.0 / (1.0 + 10**(delta))

def return_student_ranking(all_scores, all_tests, test_weights, use_w = False):
    total_score = {student: 0 for student in students}
    for t in all_tests:
        results = []
        for s in students:
            if not t in all_scores[s]:
                continue
            res = all_scores[s][t]
            if res != -1:
                results.append((res, s))
        results.sort()
        first_three = results
        if len(results) > 3:
            first_three = first_three[:3]
        C = []
        for i in range(len(first_three)):
            C.append(first_three[i][0])
        Cm = np.mean(C)
        for s in students:
            if not t in all_scores[s]:
                continue
            res = all_scores[s][t]
            if res == -1:
                final_results[s]['tests'][t] = {'score': 0, 'cost': None, 'status': 'Invalid'}
                continue
            X = test_weights[t] * min(1, (Cm/res)**(1/3))
            final_results[s]['tests'][t] = {'score': round(X, 3), 'cost': res, 'status': 'Success'}
            total_score[s] += X
    sorted_d = sorted(total_score.items(), key=operator.itemgetter(1), reverse=True)
    rank = []
    eps = 1e-6
    for i, (student, score) in enumerate(sorted_d):
        cnt = 1
        for i2, (student2, score2) in enumerate(sorted_d):
            if score2 - eps > score:
                cnt += 1
        pair_rank = (student, cnt)
        rank.append(pair_rank)
        
        final_results[student]['final_score'] = round(score, 3)
        final_results[student]['ranking'] = cnt
    return rank

def get_new_ratings(rate, standings): # current rates, standing of student ids in latest round
    seed = {}
    for i in rate:
        seed[i] = 1
        for j in rate:
            if i == j:
                continue
            seed[i] += prob(rate[j], rate[i])
    new_rates = {}
    for idx, rank in enumerate(standings): # u: user
        lo, hi = 10, 4000
        u = rank[0]
        place = rank[1]
        m_i = math.sqrt((place) * seed[u])
        while(hi - lo > 1):
            mid = (hi + lo)//2
            new_seed = 1
            for j in rate:
                if j == u:
                    continue
                new_seed += prob(rate[j], mid)
            
            if new_seed < m_i: # over valued rating
                hi = mid
            else:
                lo = mid
        R = (hi + lo) * 0.5
        d_i = (R - rate[u]) * 0.5
        new_rates[u] = int(rate[u] + d_i)
    return new_rates


def update_ratings():
    rating_files = list(Path(working_directory).rglob(rating_file))
    rate = {}
    if len(rating_files) == 0:
        print("NO ratings will set every one to 1500")
        for s in students:
            rate[s] = 1500
    else:
        with open(rating_file, 'r', encoding='utf-8') as fp:
            rate = json.load(fp)
    print("previous rates -----")
    print(rate)
    for x, y in rate.items():
        final_results[x]['prev_rating'] = y
    standings = return_student_ranking(cost, all_tests, {t: 100 for t in all_tests}, False)
    new_rates = get_new_ratings(rate, standings)
    destination = f"rating-{division}.json"
    print("new rates -----")
    print(new_rates)
    for x, y in new_rates.items():
        final_results[x]['new_rating'] = y
    with open(destination, 'w', encoding='utf-8') as fp:
        json.dump(new_rates, fp)

# %%
update_ratings()
# Out:
# NO ratings will set every one to 1500
# previous rates -----
# {'97100581': 1500, '97102044': 1500, '97106419': 1500, '96109599': 1500, '94101737': 1500, '96105875': 1500, '97105771': 1500, '96105886': 1500, '96110797': 1500, '96105829': 1500, '96109606': 1500, '96109663': 1500, '96110129': 1500, '97106262': 1500, '96105712': 1500, '97105844': 1500, '96105948': 1500, '96105983': 1500, '96109736': 1500, '96105553': 1500, '97102441': 1500, '94170733': 1500, '96109906': 1500, '97105855': 1500, '97105696': 1500, '98209048': 1500, '96105683': 1500, '97110206': 1500, '95109383': 1500, '95108008': 1500, '96101262': 1500, '96106077': 1500, '96105807': 1500, '96110067': 1500, '97106295': 1500, '96109588': 1500, '97110155': 1500, '96109747': 1500, '96109714': 1500, 'dummy': 1500}
# new rates -----
# {'97100581': 1700, '96109663': 1658, '96106077': 1634, '96109606': 1616, '97110206': 1603, '97105844': 1591, '95108008': 1581, '97105696': 1572, '96105712': 1564, '97102441': 1557, '97105855': 1550, '96105829': 1543, '97106262': 1537, '96105875': 1532, '96105683': 1526, '96105553': 1521, '96105886': 1516, '96110797': 1511, '96109747': 1506, '96109736': 1502, '94170733': 1497, '97102044': 1493, '96110067': 1489, '97106419': 1484, '96105807': 1480, '96101262': 1476, '97110155': 1472, '98209048': 1468, '96109588': 1464, '97105771': 1461, '96105948': 1457, '97106295': 1453, '96109599': 1449, '94101737': 1449, '96110129': 1449, '96105983': 1449, '96109906': 1449, '95109383': 1449, '96109714': 1449, 'dummy': 1449}
# /Users/kianooshabbasi/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars

# %%
data = sorted(final_results.items(), key= lambda item: item[1]['ranking'])

# %%
data
# Out:
# [('97100581',
#   {'ranking': 1,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 98.361, 'cost': 34471165546, 'status': 'Success'},
#     'put18': {'score': 90.627, 'cost': 46042857060, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 95.655, 'cost': 10475876, 'status': 'Success'},
#     'put7': {'score': 100.0, 'cost': 10564135670, 'status': 'Success'},
#     'put6': {'score': 97.646, 'cost': 15310216077, 'status': 'Success'},
#     'put4': {'score': 100, 'cost': 6952592999, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 100, 'cost': 1142722486, 'status': 'Success'},
#     'put8': {'score': 99.997, 'cost': 373988, 'status': 'Success'},
#     'put10': {'score': 100, 'cost': 8126830437, 'status': 'Success'},
#     'put11': {'score': 99.66, 'cost': 16344138532, 'status': 'Success'},
#     'put9': {'score': 81.701, 'cost': 5347024895, 'status': 'Success'},
#     'put13': {'score': 100, 'cost': 1059563208, 'status': 'Success'},
#     'put12': {'score': 91.335, 'cost': 485835519, 'status': 'Success'},
#     'put16': {'score': 96.013, 'cost': 11326339328, 'status': 'Success'},
#     'put17': {'score': 98.507, 'cost': 30632067812, 'status': 'Success'},
#     'put15': {'score': 100, 'cost': 50, 'status': 'Success'},
#     'put14': {'score': 100, 'cost': 3145800697, 'status': 'Success'}},
#    'final_score': 1949.5,
#    'prev_rating': 1500,
#    'new_rating': 1700}),
#  ('96109663',
#   {'ranking': 2,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 91.353, 'cost': 43028514397, 'status': 'Success'},
#     'put18': {'score': 91.978, 'cost': 44042462477, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 76.128, 'cost': 20781131, 'status': 'Success'},
#     'put7': {'score': 85.21, 'cost': 17074673372, 'status': 'Success'},
#     'put6': {'score': 90.655, 'cost': 19132059017, 'status': 'Success'},
#     'put4': {'score': 92.84, 'cost': 8688321336, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 94.105, 'cost': 1371249609, 'status': 'Success'},
#     'put8': {'score': 93.028, 'cost': 464487, 'status': 'Success'},
#     'put10': {'score': 73.732, 'cost': 21166184296, 'status': 'Success'},
#     'put11': {'score': 90.052, 'cost': 22154149770, 'status': 'Success'},
#     'put9': {'score': 84.346, 'cost': 4859481305, 'status': 'Success'},
#     'put13': {'score': 99.995, 'cost': 1059711002, 'status': 'Success'},
#     'put12': {'score': 91.335, 'cost': 485835498, 'status': 'Success'},
#     'put16': {'score': 98.196, 'cost': 10587661565, 'status': 'Success'},
#     'put17': {'score': 97.539, 'cost': 31552852729, 'status': 'Success'},
#     'put15': {'score': 98.565, 'cost': 55, 'status': 'Success'},
#     'put14': {'score': 100.0, 'cost': 3145864283, 'status': 'Success'}},
#    'final_score': 1849.059,
#    'prev_rating': 1500,
#    'new_rating': 1658}),
#  ('96106077',
#   {'ranking': 3,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 82.613, 'cost': 58180734209, 'status': 'Success'},
#     'put18': {'score': 79.468, 'cost': 68290531168, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 82.457, 'cost': 16354383, 'status': 'Success'},
#     'put7': {'score': 79.657, 'cost': 20900774915, 'status': 'Success'},
#     'put6': {'score': 89.03, 'cost': 20199271606, 'status': 'Success'},
#     'put4': {'score': 97.093, 'cost': 7595906305, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 100, 'cost': 1142742708, 'status': 'Success'},
#     'put8': {'score': 99.998, 'cost': 373970, 'status': 'Success'},
#     'put10': {'score': 87.997, 'cost': 12451333694, 'status': 'Success'},
#     'put11': {'score': 78.718, 'cost': 33166630746, 'status': 'Success'},
#     'put9': {'score': 87.354, 'cost': 4374626713, 'status': 'Success'},
#     'put13': {'score': 100, 'cost': 1059563208, 'status': 'Success'},
#     'put12': {'score': 96.149, 'cost': 416452431, 'status': 'Success'},
#     'put16': {'score': 96.092, 'cost': 11298474936, 'status': 'Success'},
#     'put17': {'score': 92.758, 'cost': 36687693724, 'status': 'Success'},
#     'put15': {'score': 97.975, 'cost': 56, 'status': 'Success'},
#     'put14': {'score': 100, 'cost': 3145800785, 'status': 'Success'}},
#    'final_score': 1847.358,
#    'prev_rating': 1500,
#    'new_rating': 1634}),
#  ('96109606',
#   {'ranking': 4,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 94.602, 'cost': 38746073774, 'status': 'Success'},
#     'put18': {'score': 88.828, 'cost': 48896576417, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 92.971, 'cost': 11409331, 'status': 'Success'},
#     'put7': {'score': 92.83, 'cost': 13205758458, 'status': 'Success'},
#     'put6': {'score': 92.304, 'cost': 18124709237, 'status': 'Success'},
#     'put4': {'score': 91.869, 'cost': 8966888848, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 82.22, 'cost': 2056010017, 'status': 'Success'},
#     'put8': {'score': 88.088, 'cost': 547095, 'status': 'Success'},
#     'put10': {'score': 95.064, 'cost': 9875620530, 'status': 'Success'},
#     'put11': {'score': 97.726, 'cost': 17334173441, 'status': 'Success'},
#     'put9': {'score': 72.116, 'cost': 7774796702, 'status': 'Success'},
#     'put13': {'score': 88.395, 'cost': 1534089822, 'status': 'Success'},
#     'put12': {'score': 87.355, 'cost': 555321132, 'status': 'Success'},
#     'put16': {'score': 94.8, 'cost': 11766719899, 'status': 'Success'},
#     'put17': {'score': 96.925, 'cost': 32155814663, 'status': 'Success'},
#     'put15': {'score': 87.358, 'cost': 79, 'status': 'Success'},
#     'put14': {'score': 81.707, 'cost': 5767126673, 'status': 'Success'}},
#    'final_score': 1825.158,
#    'prev_rating': 1500,
#    'new_rating': 1616}),
#  ('97110206',
#   {'ranking': 5,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 91.015, 'cost': 43509135224, 'status': 'Success'},
#     'put18': {'score': 99.547, 'cost': 34741329573, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 69.001, 'cost': 27909106, 'status': 'Success'},
#     'put7': {'score': 83.958, 'cost': 17850127027, 'status': 'Success'},
#     'put6': {'score': 87.561, 'cost': 21233081080, 'status': 'Success'},
#     'put4': {'score': 86.512, 'cost': 10737796328, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 99.993, 'cost': 1142998723, 'status': 'Success'},
#     'put8': {'score': 89.391, 'cost': 523516, 'status': 'Success'},
#     'put10': {'score': 82.482, 'cost': 15119846135, 'status': 'Success'},
#     'put11': {'score': 85.609, 'cost': 25785513617, 'status': 'Success'},
#     'put9': {'score': 84.345, 'cost': 4859698019, 'status': 'Success'},
#     'put13': {'score': 99.995, 'cost': 1059711002, 'status': 'Success'},
#     'put12': {'score': 81.098, 'cost': 694010409, 'status': 'Success'},
#     'put16': {'score': 94.837, 'cost': 11752724826, 'status': 'Success'},
#     'put17': {'score': 93.914, 'cost': 35348990841, 'status': 'Success'},
#     'put15': {'score': 99.17, 'cost': 54, 'status': 'Success'},
#     'put14': {'score': 81.708, 'cost': 5766968100, 'status': 'Success'}},
#    'final_score': 1810.137,
#    'prev_rating': 1500,
#    'new_rating': 1603}),
#  ('97105844',
#   {'ranking': 6,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 100, 'cost': 30038292815, 'status': 'Success'},
#     'put18': {'score': 100, 'cost': 31582288775, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 100, 'cost': 9148157, 'status': 'Success'},
#     'put7': {'score': 100, 'cost': 10563379083, 'status': 'Success'},
#     'put6': {'score': 100, 'cost': 11593734913, 'status': 'Success'},
#     'put4': {'score': 99.599, 'cost': 7036949002, 'status': 'Success'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 99.998, 'cost': 1142834349, 'status': 'Success'},
#     'put8': {'score': 100, 'cost': 373945, 'status': 'Success'},
#     'put10': {'score': 100, 'cost': 8273733631, 'status': 'Success'},
#     'put11': {'score': 100, 'cost': 14913036207, 'status': 'Success'},
#     'put9': {'score': 100, 'cost': 2915996738, 'status': 'Success'},
#     'put13': {'score': 91.688, 'cost': 1374653043, 'status': 'Success'},
#     'put12': {'score': 96.153, 'cost': 416401158, 'status': 'Success'},
#     'put16': {'score': 99.38, 'cost': 10213472960, 'status': 'Success'},
#     'put17': {'score': 100, 'cost': 26937402650, 'status': 'Success'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put14': {'score': 84.542, 'cost': 5206176447, 'status': 'Success'}},
#    'final_score': 1771.36,
#    'prev_rating': 1500,
#    'new_rating': 1591}),
#  ('95108008',
#   {'ranking': 7,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 96.275, 'cost': 36760962841, 'status': 'Success'},
#     'put18': {'score': 97.931, 'cost': 36490118838, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 88.165, 'cost': 13378755, 'status': 'Success'},
#     'put7': {'score': 87.361, 'cost': 15844633697, 'status': 'Success'},
#     'put6': {'score': 96.508, 'cost': 15858233008, 'status': 'Success'},
#     'put4': {'score': 91.015, 'cost': 9221779084, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 4, 'status': 'Success'},
#     'put5': {'score': 89.398, 'cost': 1599451225, 'status': 'Success'},
#     'put8': {'score': 91.259, 'cost': 492022, 'status': 'Success'},
#     'put10': {'score': 89.858, 'cost': 11693802942, 'status': 'Success'},
#     'put11': {'score': 88.413, 'cost': 23409213886, 'status': 'Success'},
#     'put9': {'score': 87.359, 'cost': 4373826907, 'status': 'Success'},
#     'put13': {'score': 90.026, 'cost': 1452183983, 'status': 'Success'},
#     'put12': {'score': 87.359, 'cost': 555244233, 'status': 'Success'},
#     'put16': {'score': 97.059, 'cost': 10963997389, 'status': 'Success'},
#     'put17': {'score': 94.298, 'cost': 34919306494, 'status': 'Success'},
#     'put15': {'score': 94.203, 'cost': 63, 'status': 'Success'},
#     'put14': {'score': 87.359, 'cost': 4718558223, 'status': 'Success'}},
#    'final_score': 1753.844,
#    'prev_rating': 1500,
#    'new_rating': 1581}),
#  ('97105696',
#   {'ranking': 8,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 84.674, 'cost': 54034969352, 'status': 'Success'},
#     'put18': {'score': 79.985, 'cost': 66973759212, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 75.338, 'cost': 21442035, 'status': 'Success'},
#     'put7': {'score': 75.834, 'cost': 24223579904, 'status': 'Success'},
#     'put6': {'score': 85.105, 'cost': 23124477691, 'status': 'Success'},
#     'put4': {'score': 95.252, 'cost': 8045008030, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 82.214, 'cost': 2056479901, 'status': 'Success'},
#     'put8': {'score': 88.088, 'cost': 547092, 'status': 'Success'},
#     'put10': {'score': 76.005, 'cost': 19323659049, 'status': 'Success'},
#     'put11': {'score': 78.087, 'cost': 33978228924, 'status': 'Success'},
#     'put9': {'score': 68.101, 'cost': 9232712764, 'status': 'Success'},
#     'put13': {'score': 88.395, 'cost': 1534089822, 'status': 'Success'},
#     'put12': {'score': 83.998, 'cost': 624601695, 'status': 'Success'},
#     'put16': {'score': 94.713, 'cost': 11798950837, 'status': 'Success'},
#     'put17': {'score': 90.815, 'cost': 39092748065, 'status': 'Success'},
#     'put15': {'score': 87.358, 'cost': 79, 'status': 'Success'},
#     'put14': {'score': 81.707, 'cost': 5767126677, 'status': 'Success'}},
#    'final_score': 1715.668,
#    'prev_rating': 1500,
#    'new_rating': 1572}),
#  ('96105712',
#   {'ranking': 9,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 82.551, 'cost': 58310785198, 'status': 'Success'},
#     'put18': {'score': 80.393, 'cost': 65958792485, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 75.013, 'cost': 21721911, 'status': 'Success'},
#     'put7': {'score': 73.304, 'cost': 26819079233, 'status': 'Success'},
#     'put6': {'score': 84.626, 'cost': 23519545478, 'status': 'Success'},
#     'put4': {'score': 97.093, 'cost': 7595906305, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 99.99, 'cost': 1143105057, 'status': 'Success'},
#     'put8': {'score': 93.029, 'cost': 464475, 'status': 'Success'},
#     'put10': {'score': 71.224, 'cost': 23482370854, 'status': 'Success'},
#     'put11': {'score': 81.427, 'cost': 29965613587, 'status': 'Success'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put13': {'score': 100, 'cost': 1059563208, 'status': 'Success'},
#     'put12': {'score': 91.334, 'cost': 485861166, 'status': 'Success'},
#     'put16': {'score': 95.163, 'cost': 11632484011, 'status': 'Success'},
#     'put17': {'score': 90.874, 'cost': 39016320003, 'status': 'Success'},
#     'put15': {'score': 96.286, 'cost': 59, 'status': 'Success'},
#     'put14': {'score': 100.0, 'cost': 3145864203, 'status': 'Success'}},
#    'final_score': 1712.307,
#    'prev_rating': 1500,
#    'new_rating': 1564}),
#  ('97102441',
#   {'ranking': 10,
#    'tests': {'put1': {'score': 100.0, 'cost': 5000004, 'status': 'Success'},
#     'put19': {'score': 80.11, 'cost': 63806858259, 'status': 'Success'},
#     'put18': {'score': 80.105, 'cost': 66672860033, 'status': 'Success'},
#     'put2': {'score': 100.0, 'cost': 2000300040, 'status': 'Success'},
#     'put3': {'score': 79.604, 'cost': 18176153, 'status': 'Success'},
#     'put7': {'score': 61.329, 'cost': 45797431620, 'status': 'Success'},
#     'put6': {'score': 72.434, 'cost': 37507577362, 'status': 'Success'},
#     'put4': {'score': 95.252, 'cost': 8045008032, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 94.107, 'cost': 1371192556, 'status': 'Success'},
#     'put8': {'score': 78.959, 'cost': 759642, 'status': 'Success'},
#     'put10': {'score': 69.41, 'cost': 25372139866, 'status': 'Success'},
#     'put11': {'score': 87.034, 'cost': 24539560888, 'status': 'Success'},
#     'put9': {'score': 59.845, 'cost': 13605499463, 'status': 'Success'},
#     'put13': {'score': 92.618, 'cost': 1333663175, 'status': 'Success'},
#     'put12': {'score': 87.353, 'cost': 555346758, 'status': 'Success'},
#     'put16': {'score': 88.553, 'cost': 14436807728, 'status': 'Success'},
#     'put17': {'score': 85.654, 'cost': 46593605581, 'status': 'Success'},
#     'put15': {'score': 85.589, 'cost': 84, 'status': 'Success'},
#     'put14': {'score': 87.359, 'cost': 4718653534, 'status': 'Success'}},
#    'final_score': 1685.312,
#    'prev_rating': 1500,
#    'new_rating': 1557}),
#  ('97105855',
#   {'ranking': 11,
#    'tests': {'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 98.909, 'cost': 33901402013, 'status': 'Success'},
#     'put18': {'score': 94.268, 'cost': 40910669604, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 100, 'cost': 8998485, 'status': 'Success'},
#     'put7': {'score': 99.998, 'cost': 10564597089, 'status': 'Success'},
#     'put6': {'score': 83.558, 'cost': 24433055974, 'status': 'Success'},
#     'put4': {'score': 100.0, 'cost': 6952593001, 'status': 'Success'},
#     'put5': {'score': 82.209, 'cost': 2056805743, 'status': 'Success'},
#     'put8': {'score': 95.523, 'cost': 429039, 'status': 'Success'},
#     'put10': {'score': 97.863, 'cost': 9052530697, 'status': 'Success'},
#     'put11': {'score': 97.833, 'cost': 17277449850, 'status': 'Success'},
#     'put9': {'score': 99.996, 'cost': 2916357375, 'status': 'Success'},
#     'put13': {'score': 91.676, 'cost': 1375170322, 'status': 'Success'},
#     'put12': {'score': 96.153, 'cost': 416401179, 'status': 'Success'},
#     'put16': {'score': 99.989, 'cost': 10028010874, 'status': 'Success'},
#     'put17': {'score': 86.759, 'cost': 44835520056, 'status': 'Success'}},
#    'final_score': 1624.734,
#    'prev_rating': 1500,
#    'new_rating': 1550}),
#  ('96105829',
#   {'ranking': 12,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 75.467, 'cost': 76321031533, 'status': 'Success'},
#     'put18': {'score': 66.297, 'cost': 117610041410, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 54.852, 'cost': 55556565, 'status': 'Success'},
#     'put7': {'score': 56.231, 'cost': 59416315315, 'status': 'Success'},
#     'put6': {'score': 64.147, 'cost': 54003125650, 'status': 'Success'},
#     'put4': {'score': 97.093, 'cost': 7595906284, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 94.115, 'cost': 1370808733, 'status': 'Success'},
#     'put8': {'score': 17.07, 'cost': 75180863, 'status': 'Success'},
#     'put10': {'score': 62.165, 'cost': 35316441361, 'status': 'Success'},
#     'put11': {'score': 65.202, 'cost': 58365129139, 'status': 'Success'},
#     'put9': {'score': 99.999, 'cost': 2916100965, 'status': 'Success'},
#     'put13': {'score': 96.541, 'cost': 1177584400, 'status': 'Success'},
#     'put12': {'score': 100, 'cost': 347069322, 'status': 'Success'},
#     'put16': {'score': 99.812, 'cost': 10081550648, 'status': 'Success'},
#     'put17': {'score': 98.897, 'cost': 30270703368, 'status': 'Success'},
#     'put15': {'score': 83.643, 'cost': 90, 'status': 'Success'},
#     'put14': {'score': 84.344, 'cost': 5242842470, 'status': 'Success'}},
#    'final_score': 1615.876,
#    'prev_rating': 1500,
#    'new_rating': 1543}),
#  ('97106262',
#   {'ranking': 13,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 79.925, 'cost': 64251134291, 'status': 'Success'},
#     'put18': {'score': 68.736, 'cost': 105528925663, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 56.859, 'cost': 49878964, 'status': 'Success'},
#     'put7': {'score': 58.978, 'cost': 51494307847, 'status': 'Success'},
#     'put6': {'score': 66.477, 'cost': 48520385208, 'status': 'Success'},
#     'put4': {'score': 84.787, 'cost': 11406609188, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 85.495, 'cost': 1828691104, 'status': 'Success'},
#     'put8': {'score': 87.876, 'cost': 551060, 'status': 'Success'},
#     'put10': {'score': 65.214, 'cost': 30591853902, 'status': 'Success'},
#     'put11': {'score': 68.633, 'cost': 50042292174, 'status': 'Success'},
#     'put9': {'score': 70.67, 'cost': 8261933666, 'status': 'Success'},
#     'put13': {'score': 87.702, 'cost': 1570704791, 'status': 'Success'},
#     'put12': {'score': 83.995, 'cost': 624652968, 'status': 'Success'},
#     'put16': {'score': 97.059, 'cost': 10963997389, 'status': 'Success'},
#     'put17': {'score': 83.11, 'cost': 51005825098, 'status': 'Success'},
#     'put15': {'score': 84.92, 'cost': 86, 'status': 'Success'},
#     'put14': {'score': 84.344, 'cost': 5242810737, 'status': 'Success'}},
#    'final_score': 1614.78,
#    'prev_rating': 1500,
#    'new_rating': 1537}),
#  ('96105875',
#   {'ranking': 14,
#    'tests': {'put18': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 74.348, 'cost': 79819770088, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 90.245, 'cost': 12474824, 'status': 'Success'},
#     'put7': {'score': 68.944, 'cost': 32235583346, 'status': 'Success'},
#     'put6': {'score': 89.161, 'cost': 20110146839, 'status': 'Success'},
#     'put4': {'score': 82.54, 'cost': 12363669109, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 72.735, 'cost': 2969825693, 'status': 'Success'},
#     'put8': {'score': 93.03, 'cost': 464461, 'status': 'Success'},
#     'put10': {'score': 84.275, 'cost': 14174830303, 'status': 'Success'},
#     'put11': {'score': 73.465, 'cost': 40802278668, 'status': 'Success'},
#     'put9': {'score': 66.947, 'cost': 9718529937, 'status': 'Success'},
#     'put13': {'score': 68.759, 'cost': 3259339214, 'status': 'Success'},
#     'put12': {'score': 96.149, 'cost': 416452410, 'status': 'Success'},
#     'put16': {'score': 94.326, 'cost': 11944867034, 'status': 'Success'},
#     'put17': {'score': 77.799, 'cost': 62179166063, 'status': 'Success'},
#     'put15': {'score': 96.286, 'cost': 59, 'status': 'Success'},
#     'put14': {'score': 79.37, 'cost': 6291537968, 'status': 'Success'}},
#    'final_score': 1608.381,
#    'prev_rating': 1500,
#    'new_rating': 1532}),
#  ('96105683',
#   {'ranking': 15,
#    'tests': {'put17': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put1': {'score': 89.39, 'cost': 7000004, 'status': 'Success'},
#     'put19': {'score': 78.376, 'cost': 68135919606, 'status': 'Success'},
#     'put18': {'score': 80.723, 'cost': 65152623615, 'status': 'Success'},
#     'put2': {'score': 79.372, 'cost': 4000300040, 'status': 'Success'},
#     'put3': {'score': 68.975, 'cost': 27940576, 'status': 'Success'},
#     'put7': {'score': 68.401, 'cost': 33009136442, 'status': 'Success'},
#     'put6': {'score': 78.49, 'cost': 29477849700, 'status': 'Success'},
#     'put4': {'score': 83.446, 'cost': 11965566492, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 99.981, 'cost': 1143418385, 'status': 'Success'},
#     'put8': {'score': 83.531, 'cost': 641616, 'status': 'Success'},
#     'put10': {'score': 71.011, 'cost': 23694245784, 'status': 'Success'},
#     'put11': {'score': 72.587, 'cost': 42301065939, 'status': 'Success'},
#     'put9': {'score': 72.114, 'cost': 7775482268, 'status': 'Success'},
#     'put13': {'score': 91.782, 'cost': 1370425938, 'status': 'Success'},
#     'put12': {'score': 81.096, 'cost': 694061724, 'status': 'Success'},
#     'put16': {'score': 88.008, 'cost': 14706630352, 'status': 'Success'},
#     'put15': {'score': 99.17, 'cost': 54, 'status': 'Success'},
#     'put14': {'score': 100.0, 'cost': 3145864299, 'status': 'Success'}},
#    'final_score': 1586.454,
#    'prev_rating': 1500,
#    'new_rating': 1526}),
#  ('96105553',
#   {'ranking': 16,
#    'tests': {'put1': {'score': 94.104, 'cost': 6000003, 'status': 'Success'},
#     'put19': {'score': 76.444, 'cost': 73432771699, 'status': 'Success'},
#     'put18': {'score': 71.945, 'cost': 92028197344, 'status': 'Success'},
#     'put2': {'score': 87.36, 'cost': 3000300030, 'status': 'Success'},
#     'put3': {'score': 61.14, 'cost': 40116699, 'status': 'Success'},
#     'put7': {'score': 60.573, 'cost': 47532981130, 'status': 'Success'},
#     'put6': {'score': 70.048, 'cost': 41471855725, 'status': 'Success'},
#     'put4': {'score': 81.279, 'cost': 12948125987, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 89.377, 'cost': 1600603585, 'status': 'Success'},
#     'put8': {'score': 82.369, 'cost': 669146, 'status': 'Success'},
#     'put10': {'score': 64.604, 'cost': 31466037479, 'status': 'Success'},
#     'put11': {'score': 66.77, 'cost': 54349190396, 'status': 'Success'},
#     'put9': {'score': 63.899, 'cost': 11176590366, 'status': 'Success'},
#     'put13': {'score': 91.691, 'cost': 1374505249, 'status': 'Success'},
#     'put12': {'score': 78.56, 'cost': 763470438, 'status': 'Success'},
#     'put16': {'score': 84.373, 'cost': 16690363065, 'status': 'Success'},
#     'put17': {'score': 79.919, 'cost': 57361573525, 'status': 'Success'},
#     'put15': {'score': 95.222, 'cost': 61, 'status': 'Success'},
#     'put14': {'score': 84.344, 'cost': 5242810737, 'status': 'Success'}},
#    'final_score': 1584.021,
#    'prev_rating': 1500,
#    'new_rating': 1521}),
#  ('96105886',
#   {'ranking': 17,
#    'tests': {'put1': {'score': 94.104, 'cost': 6000003, 'status': 'Success'},
#     'put19': {'score': 70.394, 'cost': 94038729498, 'status': 'Success'},
#     'put18': {'score': 71.945, 'cost': 92028197344, 'status': 'Success'},
#     'put2': {'score': 87.36, 'cost': 3000300030, 'status': 'Success'},
#     'put3': {'score': 61.14, 'cost': 40116699, 'status': 'Success'},
#     'put7': {'score': 60.573, 'cost': 47533002743, 'status': 'Success'},
#     'put6': {'score': 70.048, 'cost': 41471855725, 'status': 'Success'},
#     'put4': {'score': 81.279, 'cost': 12948125987, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 89.377, 'cost': 1600603585, 'status': 'Success'},
#     'put8': {'score': 82.369, 'cost': 669146, 'status': 'Success'},
#     'put10': {'score': 64.604, 'cost': 31466037479, 'status': 'Success'},
#     'put11': {'score': 64.842, 'cost': 59342969682, 'status': 'Success'},
#     'put9': {'score': 63.899, 'cost': 11176590366, 'status': 'Success'},
#     'put13': {'score': 91.691, 'cost': 1374505249, 'status': 'Success'},
#     'put12': {'score': 78.56, 'cost': 763470438, 'status': 'Success'},
#     'put16': {'score': 84.373, 'cost': 16690363065, 'status': 'Success'},
#     'put17': {'score': 79.919, 'cost': 57361573525, 'status': 'Success'},
#     'put15': {'score': 93.227, 'cost': 65, 'status': 'Success'},
#     'put14': {'score': 87.359, 'cost': 4718589956, 'status': 'Success'}},
#    'final_score': 1577.063,
#    'prev_rating': 1500,
#    'new_rating': 1516}),
#  ('96110797',
#   {'ranking': 18,
#    'tests': {'put1': {'score': 94.104, 'cost': 6000003, 'status': 'Success'},
#     'put19': {'score': 70.372, 'cost': 94127405302, 'status': 'Success'},
#     'put18': {'score': 72.178, 'cost': 91140555460, 'status': 'Success'},
#     'put2': {'score': 87.36, 'cost': 3000300030, 'status': 'Success'},
#     'put3': {'score': 61.14, 'cost': 40116699, 'status': 'Success'},
#     'put7': {'score': 60.573, 'cost': 47532981130, 'status': 'Success'},
#     'put6': {'score': 70.271, 'cost': 41078595554, 'status': 'Success'},
#     'put4': {'score': 81.279, 'cost': 12948125987, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 85.49, 'cost': 1829011098, 'status': 'Success'},
#     'put8': {'score': 80.08, 'cost': 728194, 'status': 'Success'},
#     'put10': {'score': 62.73, 'cost': 34371464094, 'status': 'Success'},
#     'put11': {'score': 64.623, 'cost': 59948352688, 'status': 'Success'},
#     'put9': {'score': 64.853, 'cost': 10690749086, 'status': 'Success'},
#     'put13': {'score': 91.693, 'cost': 1374431352, 'status': 'Success'},
#     'put12': {'score': 78.56, 'cost': 763470438, 'status': 'Success'},
#     'put16': {'score': 84.373, 'cost': 16690363065, 'status': 'Success'},
#     'put17': {'score': 79.523, 'cost': 58223717393, 'status': 'Success'},
#     'put15': {'score': 94.203, 'cost': 63, 'status': 'Success'},
#     'put14': {'score': 87.359, 'cost': 4718558223, 'status': 'Success'}},
#    'final_score': 1570.762,
#    'prev_rating': 1500,
#    'new_rating': 1511}),
#  ('96109747',
#   {'ranking': 19,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 73.588, 'cost': 82318714975, 'status': 'Success'},
#     'put18': {'score': 66.6, 'cost': 116014598360, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 54.41, 'cost': 56921673, 'status': 'Success'},
#     'put7': {'score': 63.043, 'cost': 42161877272, 'status': 'Success'},
#     'put6': {'score': 69.333, 'cost': 42767724757, 'status': 'Success'},
#     'put4': {'score': 86.97, 'cost': 10569084350, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 76.89, 'cost': 2513928178, 'status': 'Success'},
#     'put8': {'score': 79.234, 'cost': 751758, 'status': 'Success'},
#     'put10': {'score': 58.241, 'cost': 42946737523, 'status': 'Success'},
#     'put11': {'score': 67.087, 'cost': 53581582044, 'status': 'Success'},
#     'put9': {'score': 64.852, 'cost': 10691164783, 'status': 'Success'},
#     'put13': {'score': 77.947, 'cost': 2237351636, 'status': 'Success'},
#     'put12': {'score': 83.994, 'cost': 624678615, 'status': 'Success'},
#     'put16': {'score': 86.935, 'cost': 15257624399, 'status': 'Success'},
#     'put17': {'score': 83.492, 'cost': 50308513321, 'status': 'Success'},
#     'put15': {'score': 80.489, 'cost': 101, 'status': 'Success'},
#     'put14': {'score': 77.281, 'cost': 6815695303, 'status': 'Success'}},
#    'final_score': 1550.386,
#    'prev_rating': 1500,
#    'new_rating': 1506}),
#  ('96109736',
#   {'ranking': 20,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 63.649, 'cost': 127216860456, 'status': 'Success'},
#     'put18': {'score': 67.526, 'cost': 111304705788, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 74.385, 'cost': 22276555, 'status': 'Success'},
#     'put7': {'score': 66.179, 'cost': 36448220394, 'status': 'Success'},
#     'put6': {'score': 70.657, 'cost': 40408874455, 'status': 'Success'},
#     'put4': {'score': 86.444, 'cost': 10763295883, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 50.872, 'cost': 8679922533, 'status': 'Success'},
#     'put8': {'score': 87.876, 'cost': 551060, 'status': 'Success'},
#     'put10': {'score': 64.026, 'cost': 32326386031, 'status': 'Success'},
#     'put11': {'score': 69.743, 'cost': 47690920824, 'status': 'Success'},
#     'put9': {'score': 54.052, 'cost': 18465527904, 'status': 'Success'},
#     'put13': {'score': 91.691, 'cost': 1374505249, 'status': 'Success'},
#     'put12': {'score': 83.995, 'cost': 624652968, 'status': 'Success'},
#     'put16': {'score': 71.542, 'cost': 27377347445, 'status': 'Success'},
#     'put17': {'score': 69.341, 'cost': 87820057219, 'status': 'Success'},
#     'put15': {'score': 94.203, 'cost': 63, 'status': 'Success'},
#     'put14': {'score': 64.769, 'cost': 11577971471, 'status': 'Success'}},
#    'final_score': 1530.95,
#    'prev_rating': 1500,
#    'new_rating': 1502}),
#  ('94170733',
#   {'ranking': 21,
#    'tests': {'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 87.963, 'cost': 48196524359, 'status': 'Success'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 75.111, 'cost': 21637031, 'status': 'Success'},
#     'put7': {'score': 75.835, 'cost': 24222884564, 'status': 'Success'},
#     'put6': {'score': 89.448, 'cost': 19917174649, 'status': 'Success'},
#     'put4': {'score': 95.252, 'cost': 8045008030, 'status': 'Success'},
#     'put5': {'score': 82.214, 'cost': 2056437377, 'status': 'Success'},
#     'put8': {'score': 88.088, 'cost': 547092, 'status': 'Success'},
#     'put10': {'score': 79.753, 'cost': 16725348623, 'status': 'Success'},
#     'put11': {'score': 78.087, 'cost': 33978228974, 'status': 'Success'},
#     'put9': {'score': 75.398, 'cost': 6803247568, 'status': 'Success'},
#     'put13': {'score': 88.4, 'cost': 1533794234, 'status': 'Success'},
#     'put12': {'score': 83.998, 'cost': 624601695, 'status': 'Success'},
#     'put16': {'score': 98.299, 'cost': 10554162157, 'status': 'Success'},
#     'put15': {'score': 87.358, 'cost': 79, 'status': 'Success'},
#     'put14': {'score': 81.707, 'cost': 5767126677, 'status': 'Success'}},
#    'final_score': 1466.911,
#    'prev_rating': 1500,
#    'new_rating': 1497}),
#  ('97102044',
#   {'ranking': 22,
#    'tests': {'put19': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 71.629, 'cost': 24948700, 'status': 'Success'},
#     'put7': {'score': 79.313, 'cost': 21173761550, 'status': 'Success'},
#     'put6': {'score': 86.302, 'cost': 22175623010, 'status': 'Success'},
#     'put4': {'score': 87.921, 'cost': 10229838136, 'status': 'Success'},
#     'put20': {'score': 100, 'cost': 0, 'status': 'Success'},
#     'put5': {'score': 99.99, 'cost': 1143111698, 'status': 'Success'},
#     'put8': {'score': 83.704, 'cost': 637643, 'status': 'Success'},
#     'put10': {'score': 75.881, 'cost': 19418355590, 'status': 'Success'},
#     'put11': {'score': 86.723, 'cost': 24804426676, 'status': 'Success'},
#     'put9': {'score': 100, 'cost': 2915935952, 'status': 'Success'},
#     'put13': {'score': 88.397, 'cost': 1533942028, 'status': 'Success'},
#     'put12': {'score': 87.357, 'cost': 555269880, 'status': 'Success'},
#     'put15': {'score': 96.836, 'cost': 58, 'status': 'Success'},
#     'put14': {'score': 90.856, 'cost': 4194369247, 'status': 'Success'}},
#    'final_score': 1434.91,
#    'prev_rating': 1500,
#    'new_rating': 1493}),
#  ('96110067',
#   {'ranking': 23,
#    'tests': {'put19': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put18': {'score': 92.243, 'cost': 43664787175, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 81.067, 'cost': 17210131, 'status': 'Success'},
#     'put7': {'score': 96.775, 'cost': 11655829040, 'status': 'Success'},
#     'put4': {'score': 100, 'cost': 6952592999, 'status': 'Success'},
#     'put5': {'score': 99.985, 'cost': 1143267205, 'status': 'Success'},
#     'put8': {'score': 100, 'cost': 373943, 'status': 'Success'},
#     'put10': {'score': 72.226, 'cost': 22518247440, 'status': 'Success'},
#     'put11': {'score': 79.432, 'cost': 32281327071, 'status': 'Success'},
#     'put9': {'score': 99.995, 'cost': 2916405607, 'status': 'Success'},
#     'put13': {'score': 91.779, 'cost': 1370573732, 'status': 'Success'},
#     'put12': {'score': 96.149, 'cost': 416452410, 'status': 'Success'},
#     'put16': {'score': 100, 'cost': 9964867226, 'status': 'Success'},
#     'put17': {'score': 90.961, 'cost': 38904666479, 'status': 'Success'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 1400.612,
#    'prev_rating': 1500,
#    'new_rating': 1489}),
#  ('97106419',
#   {'ranking': 24,
#    'tests': {'put1': {'score': 94.104, 'cost': 6000003, 'status': 'Success'},
#     'put19': {'score': 64.509, 'cost': 122196632774, 'status': 'Success'},
#     'put18': {'score': 70.116, 'cost': 99421621066, 'status': 'Success'},
#     'put2': {'score': 87.36, 'cost': 3000300030, 'status': 'Success'},
#     'put3': {'score': 60.388, 'cost': 41635410, 'status': 'Success'},
#     'put7': {'score': 58.172, 'cost': 53665144643, 'status': 'Success'},
#     'put6': {'score': 67.258, 'cost': 46849877132, 'status': 'Success'},
#     'put4': {'score': 81.279, 'cost': 12948125987, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 39, 'status': 'Success'},
#     'put5': {'score': 54.641, 'cost': 7004943561, 'status': 'Success'},
#     'put8': {'score': 10.762, 'cost': 300038367, 'status': 'Success'},
#     'put10': {'score': 61.069, 'cost': 37252454526, 'status': 'Success'},
#     'put11': {'score': 63.427, 'cost': 63404208420, 'status': 'Success'},
#     'put9': {'score': 57.091, 'cost': 15670684378, 'status': 'Success'},
#     'put13': {'score': 89.21, 'cost': 1492378647, 'status': 'Success'},
#     'put12': {'score': 78.56, 'cost': 763470438, 'status': 'Success'},
#     'put16': {'score': 80.595, 'cost': 19149120776, 'status': 'Success'},
#     'put17': {'score': 79.919, 'cost': 57361573525, 'status': 'Success'},
#     'put15': {'score': 5.456, 'cost': 324241, 'status': 'Success'},
#     'put14': {'score': 84.543, 'cost': 5205890482, 'status': 'Success'}},
#    'final_score': 1248.459,
#    'prev_rating': 1500,
#    'new_rating': 1484}),
#  ('96105807',
#   {'ranking': 25,
#    'tests': {'put1': {'score': 85.499, 'cost': 8000004, 'status': 'Success'},
#     'put19': {'score': 67.063, 'cost': 108758547342, 'status': 'Success'},
#     'put18': {'score': 67.165, 'cost': 113108067394, 'status': 'Success'},
#     'put2': {'score': 79.371, 'cost': 4000400040, 'status': 'Success'},
#     'put3': {'score': 59.006, 'cost': 44629188, 'status': 'Success'},
#     'put7': {'score': 58.154, 'cost': 53715736956, 'status': 'Success'},
#     'put6': {'score': 64.266, 'cost': 53702847450, 'status': 'Success'},
#     'put4': {'score': 77.02, 'cost': 15217312093, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 28, 'status': 'Success'},
#     'put5': {'score': 60.432, 'cost': 5178025938, 'status': 'Success'},
#     'put8': {'score': 13.543, 'cost': 150542682, 'status': 'Success'},
#     'put10': {'score': 60.293, 'cost': 38709580404, 'status': 'Success'},
#     'put11': {'score': 62.466, 'cost': 66373080185, 'status': 'Success'},
#     'put9': {'score': 58.923, 'cost': 14253632005, 'status': 'Success'},
#     'put13': {'score': 72.119, 'cost': 2824776396, 'status': 'Success'},
#     'put12': {'score': 72.493, 'cost': 971645370, 'status': 'Success'},
#     'put16': {'score': 79.818, 'cost': 19713650579, 'status': 'Success'},
#     'put17': {'score': 77.263, 'cost': 63482343918, 'status': 'Success'},
#     'put15': {'score': 5.893, 'cost': 257320, 'status': 'Success'},
#     'put14': {'score': 67.75, 'cost': 10116038144, 'status': 'Success'}},
#    'final_score': 1188.539,
#    'prev_rating': 1500,
#    'new_rating': 1480}),
#  ('96101262',
#   {'ranking': 26,
#    'tests': {'put1': {'score': 85.499, 'cost': 8000004, 'status': 'Success'},
#     'put19': {'score': 61.883, 'cost': 138426107557, 'status': 'Success'},
#     'put18': {'score': 62.344, 'cost': 141431796552, 'status': 'Success'},
#     'put2': {'score': 79.371, 'cost': 4000400040, 'status': 'Success'},
#     'put3': {'score': 55.484, 'cost': 53679213, 'status': 'Success'},
#     'put7': {'score': 59.821, 'cost': 49348971677, 'status': 'Success'},
#     'put6': {'score': 61.938, 'cost': 59989514754, 'status': 'Success'},
#     'put4': {'score': 77.02, 'cost': 15217312093, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 42, 'status': 'Success'},
#     'put5': {'score': 58.233, 'cost': 5787057084, 'status': 'Success'},
#     'put8': {'score': 17.028, 'cost': 75735801, 'status': 'Success'},
#     'put10': {'score': 58.411, 'cost': 42573704691, 'status': 'Success'},
#     'put11': {'score': 62.368, 'cost': 66687966154, 'status': 'Success'},
#     'put9': {'score': 54.992, 'cost': 17534535341, 'status': 'Success'},
#     'put13': {'score': 68.803, 'cost': 3253216936, 'status': 'Success'},
#     'put12': {'score': 72.493, 'cost': 971645370, 'status': 'Success'},
#     'put16': {'score': 77.878, 'cost': 21224404412, 'status': 'Success'},
#     'put17': {'score': 77.263, 'cost': 63482343918, 'status': 'Success'},
#     'put15': {'score': 6.3, 'cost': 210636, 'status': 'Success'},
#     'put14': {'score': 66.696, 'cost': 10603211762, 'status': 'Success'}},
#    'final_score': 1163.823,
#    'prev_rating': 1500,
#    'new_rating': 1476}),
#  ('97110155',
#   {'ranking': 27,
#    'tests': {'put1': {'score': 79.37, 'cost': 10000006, 'status': 'Success'},
#     'put19': {'score': 59.72, 'cost': 154016423572, 'status': 'Success'},
#     'put18': {'score': 60.425, 'cost': 155339707460, 'status': 'Success'},
#     'put2': {'score': 69.338, 'cost': 6000400060, 'status': 'Success'},
#     'put3': {'score': 51.834, 'cost': 65834890, 'status': 'Success'},
#     'put7': {'score': 51.062, 'cost': 79348423486, 'status': 'Success'},
#     'put6': {'score': 57.3, 'cost': 75764422488, 'status': 'Success'},
#     'put4': {'score': 68.352, 'cost': 21771802405, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 28, 'status': 'Success'},
#     'put5': {'score': 58.748, 'cost': 5635972026, 'status': 'Success'},
#     'put8': {'score': 9.4, 'cost': 450238649, 'status': 'Success'},
#     'put10': {'score': 52.566, 'cost': 58411159881, 'status': 'Success'},
#     'put11': {'score': 54.306, 'cost': 101014109469, 'status': 'Success'},
#     'put9': {'score': 53.509, 'cost': 19032582120, 'status': 'Success'},
#     'put13': {'score': 83.705, 'cost': 1806673278, 'status': 'Success'},
#     'put12': {'score': 64.367, 'cost': 1388097780, 'status': 'Success'},
#     'put16': {'score': 68.95, 'cost': 30582080335, 'status': 'Success'},
#     'put17': {'score': 69.058, 'cost': 88905337626, 'status': 'Success'},
#     'put15': {'score': 6.141, 'cost': 227454, 'status': 'Success'},
#     'put14': {'score': 79.684, 'cost': 6217506988, 'status': 'Success'}},
#    'final_score': 1097.836,
#    'prev_rating': 1500,
#    'new_rating': 1472}),
#  ('98209048',
#   {'ranking': 28,
#    'tests': {'put1': {'score': 94.104, 'cost': 6000005, 'status': 'Success'},
#     'put19': {'score': 69.275, 'cost': 98672596965, 'status': 'Success'},
#     'put18': {'score': 70.092, 'cost': 99523411946, 'status': 'Success'},
#     'put2': {'score': 87.36, 'cost': 3000300030, 'status': 'Success'},
#     'put3': {'score': 55.903, 'cost': 52482059, 'status': 'Success'},
#     'put7': {'score': 50.578, 'cost': 81648940470, 'status': 'Success'},
#     'put6': {'score': 68.151, 'cost': 45033044973, 'status': 'Success'},
#     'put4': {'score': 84.914, 'cost': 11355610120, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 37, 'status': 'Success'},
#     'put5': {'score': 51.024, 'cost': 8602709634, 'status': 'Success'},
#     'put8': {'score': 11.846, 'cost': 224967823, 'status': 'Success'},
#     'put10': {'score': 61.732, 'cost': 36064518077, 'status': 'Success'},
#     'put11': {'score': 50.574, 'cost': 125067227088, 'status': 'Success'},
#     'put9': {'score': 73.413, 'cost': 7370172268, 'status': 'Success'},
#     'put13': {'score': 53.118, 'cost': 7069552939, 'status': 'Success'},
#     'put12': {'score': 66.668, 'cost': 1249254726, 'status': 'Success'},
#     'put16': {'score': 91.936, 'cost': 12900870450, 'status': 'Success'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put15': {'score': 4.309, 'cost': 658308, 'status': 'Success'},
#     'put14': {'score': 51.11, 'cost': 23562541670, 'status': 'Success'}},
#    'final_score': 1096.105,
#    'prev_rating': 1500,
#    'new_rating': 1468}),
#  ('96109588',
#   {'ranking': 29,
#    'tests': {'put14': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 57.108, 'cost': 176128404466, 'status': 'Success'},
#     'put18': {'score': 52.351, 'cost': 238864540413, 'status': 'Success'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 99.316, 'cost': 9359554, 'status': 'Success'},
#     'put7': {'score': 26.024, 'cost': 599373100092, 'status': 'Success'},
#     'put6': {'score': 41.219, 'cost': 203544402659, 'status': 'Success'},
#     'put4': {'score': 7.115, 'cost': 19304101370368, 'status': 'Success'},
#     'put20': {'score': 0.0, 'cost': 12, 'status': 'Success'},
#     'put5': {'score': 70.412, 'cost': 3273588981, 'status': 'Success'},
#     'put8': {'score': 99.998, 'cost': 373971, 'status': 'Success'},
#     'put10': {'score': 23.33, 'cost': 668191022846, 'status': 'Success'},
#     'put11': {'score': 26.752, 'cost': 844999802336, 'status': 'Success'},
#     'put9': {'score': 81.101, 'cost': 5466512341, 'status': 'Success'},
#     'put13': {'score': 77.062, 'cost': 2315299118, 'status': 'Success'},
#     'put12': {'score': 100, 'cost': 347043696, 'status': 'Success'},
#     'put16': {'score': 16.742, 'cost': 2136354063596, 'status': 'Success'},
#     'put17': {'score': 19.637, 'cost': 3866792478753, 'status': 'Success'},
#     'put15': {'score': 85.252, 'cost': 85, 'status': 'Success'}},
#    'final_score': 1083.418,
#    'prev_rating': 1500,
#    'new_rating': 1464}),
#  ('97105771',
#   {'ranking': 30,
#    'tests': {'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 100, 'cost': 2000300020, 'status': 'Success'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 97.093, 'cost': 7595906305, 'status': 'Success'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 64.478, 'cost': 4263093722, 'status': 'Success'},
#     'put8': {'score': 10.76, 'cost': 300179983, 'status': 'Success'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 69.562, 'cost': 8663150194, 'status': 'Success'},
#     'put13': {'score': 66.493, 'cost': 3604126536, 'status': 'Success'},
#     'put12': {'score': 78.565, 'cost': 763342245, 'status': 'Success'},
#     'put16': {'score': 96.557, 'cost': 11135976968, 'status': 'Success'},
#     'put17': {'score': 94.09, 'cost': 35150905610, 'status': 'Success'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 777.598,
#    'prev_rating': 1500,
#    'new_rating': 1461}),
#  ('96105948',
#   {'ranking': 31,
#    'tests': {'put6': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 100, 'cost': 5000002, 'status': 'Success'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 100.0, 'cost': 2000300040, 'status': 'Success'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 80.853, 'cost': 13153839346, 'status': 'Success'},
#     'put5': {'score': 60.132, 'cost': 5255949494, 'status': 'Success'},
#     'put8': {'score': 8.546, 'cost': 599116400, 'status': 'Success'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 63.83, 'cost': 11213060036, 'status': 'Success'},
#     'put13': {'score': 87.769, 'cost': 1567142759, 'status': 'Success'},
#     'put12': {'score': 78.564, 'cost': 763367892, 'status': 'Success'},
#     'put16': {'score': 75.051, 'cost': 23714388558, 'status': 'Success'},
#     'put17': {'score': 82.36, 'cost': 52411168406, 'status': 'Success'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 737.104,
#    'prev_rating': 1500,
#    'new_rating': 1457}),
#  ('97106295',
#   {'ranking': 32,
#    'tests': {'put1': {'score': 85.499, 'cost': 8000004, 'status': 'Success'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 79.371, 'cost': 4000400040, 'status': 'Success'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 164.87,
#    'prev_rating': 1500,
#    'new_rating': 1453}),
#  ('96109599',
#   {'ranking': 33,
#    'tests': {'put1': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('94101737',
#   {'ranking': 33,
#    'tests': {'put19': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('96110129',
#   {'ranking': 33,
#    'tests': {'put1': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Runtime Error'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('96105983',
#   {'ranking': 33,
#    'tests': {'put1': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Runtime Error'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('96109906',
#   {'ranking': 33,
#    'tests': {'put19': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     'put1': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('95109383',
#   {'ranking': 33,
#    'tests': {'put1': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put6': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('96109714',
#   {'ranking': 33,
#    'tests': {'put6': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put11': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put12': {'score': 0, 'cost': None, 'status': 'Runtime Error'},
#     'put1': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put7': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     'put14': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449}),
#  ('dummy',
#   {'ranking': 33,
#    'tests': {'put1': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put19': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put18': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put2': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put3': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put7': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put6': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put4': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put20': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put5': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put8': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put10': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put11': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put9': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put13': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put12': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put16': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put17': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put15': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     'put14': {'score': 0, 'cost': None, 'status': 'No Submission'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1449})]

# %%
import xlsxwriter


def export_excel(data):

    workbook = xlsxwriter.Workbook(f'results-{division}.xlsx')
    worksheet = workbook.add_worksheet()
    cell_format1 = workbook.add_format({'bg_color': 'green'})
    cell_format2 = workbook.add_format({'bg_color': 'red'})

    col = 0
    worksheet.write(0, 0, "Ranking")
    worksheet.write(0, 1, "Student ID")
    worksheet.write(0, 2, "Final score")
    worksheet.write(0, 3, "Prev rating")
    worksheet.write(0, 4, "Rating change")
    worksheet.write(0, 5, "New rating")
    worksheet.write(0, 6, "")

    for i in range(1,21):
        worksheet.write(0, i + 6, f"Test {i} score\n(cost)")
        
    for i in range(len(data)):
        col = 0
        worksheet.write(2*i+1, col, data[i][1]["ranking"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][0])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["final_score"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["prev_rating"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["new_rating"] - data[i][1]["prev_rating"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["new_rating"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, "")
        worksheet.write(2*i+2, col, "")
        col += 1
        for num in sorted(map(lambda x: x[3:], data[i][1]["tests"]), key=int):
            worksheet.write(2 * i + 1, col, data[i][1]["tests"][f"put{num}"]["score"])
            if data[i][1]["tests"][f"put{num}"]['status'] == "Success":
                worksheet.write(2 * i + 2, col, f'({data[i][1]["tests"][f"put{num}"]["cost"]})')
            else:
                worksheet.write(2 * i + 2, col, f'({data[i][1]["tests"][f"put{num}"]["status"]})')
        
            col += 1

    workbook.close()

# %%
export_excel(data)

# %%
os.remove(judge)
