# %%
import os
from pathlib import Path
import numpy as np
import operator
import json
import math

# %%
DIVISIONS = ['div1', 'div2', 'all']

DIV_THRESHOLD = 1500

# %%
division = 'all'

# %%
time_limit = 1

# %%
all_students = ['94101737', '94101975', '95105657', '95106494', '95108008', '95109242', '95109383', '96101262', '96101913', '96104881', '96105553', '96105575', '96105626', '96105637', '96105672', '96105683', '96105712', '96105807', '96105829', '96105853', '96105864', '96105875', '96105886', '96105948', '96105983', '96106033', '96106077', '96106117', '96109588', '96109599', '96109606', '96109663', '96109714', '96109736', '96109747', '96109758', '96109899', '96109906', '96110067', '96110129', '96110797', '97100581', '97102044', '97102441', '97105696', '97105771', '97105844', '97105855', '97106262', '97106295', '97106419', '97110155', '97110206', '97213093', '98209048']

# %%
import shutil

working_directory = os.path.abspath('')
os.chdir(working_directory)

submissions_path = Path(os.path.join(working_directory, 'submissions'))

tests_path = Path(os.path.join(working_directory, 'tests'))

executables_path = os.path.join(working_directory, 'executables')

time_limit = 1 # in seconds

rating_file = 'rating.json'

if os.path.exists(executables_path):
    shutil.rmtree(executables_path)

os.mkdir(executables_path)
    
outputs_path = Path(os.path.join(working_directory, 'outputs'))
    
if os.path.exists(outputs_path):
    shutil.rmtree(outputs_path)    
    
os.mkdir(outputs_path)

# %%
students = list(os.walk(submissions_path))[0][1]

if division != 'div1':
    students += ['dummy']

try:
    with open(rating_file, 'r', encoding='utf-8') as fp:
        rate = json.load(fp)

    for student in students:
        if student not in rate:
            print(f'FATAL ERROR: {student} has no rating!')

    for std in rate:
        if std not in students:
            print(f'{std} did not submit at this round.')
            students.append(std)
except FileNotFoundError:
    print('No rating file.')

if division == 'div1':
    students = list(filter(lambda x: rate[x] >= DIV_THRESHOLD, students))
elif division == 'div2':
    students = list(filter(lambda x: rate[x] < DIV_THRESHOLD, students))
            
final_results = {student: {'ranking': None, 'tests': {}, 'final_score': 0, 'prev_rating': 0, 'new_rating': 0} for student in students}
# Out:
# No rating file.

# %%
print(division, 'contest')
print(f'{len(students)} students we have: {students}')
# Out:
# all contest
# 15 students we have: ['97100581', '96105886', '96110797', '96109606', '96109663', '96105948', '97102441', '97105696', '98209048', '97110206', '95109383', '95108008', '96101262', '97110155', 'dummy']

# %%
print(submissions_path)
print(working_directory)
print(tests_path)
print(executables_path)
# Out:
# /Users/kianooshabbasi/Downloads/hello/submissions
# /Users/kianooshabbasi/Downloads/hello
# /Users/kianooshabbasi/Downloads/hello/tests
# /Users/kianooshabbasi/Downloads/hello/executables

# %%
all_tests = list(map(lambda path: os.path.basename(path).split('in')[1].split('.txt')[0], tests_path.rglob('*.txt')))

# %%
print('Compiling codes...')

errors = 0

for student in students:
    cpp_files = list(Path(os.path.join(submissions_path, student)).rglob('*.c*'))
    ans = [] 
    for i in cpp_files:
        if i.name.endswith(".cxx") or i.name.endswith(".cpp"):
            ans.append(i)
    cpp_files = ans
    
    if len(cpp_files) != 1:
        print(f'Something wrong with {student}\'s files. Could not find the cpp file')
        final_results[student]['tests'] = {test: {'score': 0, 'cost': None, 'status': 'No Submission'} for test in all_tests}
        errors += 1
        continue

    cpp_file = cpp_files[0]
    output_file = os.path.join(submissions_path, student, 'output-runnable')
    code = os.system(f'g++ {cpp_file} -std=c++14 -O2 -o {output_file}')
    
    if code != 0:
        print(f'Could not compile {student}\'s code.')
        final_results[student]['tests'] = {test: {'score': 0, 'cost': None, 'status': 'Compiler Error'} for test in all_tests}
        errors += 1
        continue
    
    
    shutil.move(output_file, os.path.join(executables_path, f'{student}.exec'))

print(f'Compilation finished for {len(students)} codes: {errors} error(s).')
print('\n=================================================\n')
# Out:
# Compiling codes...
# Could not compile 96109663's code.
# Something wrong with dummy's files. Could not find the cpp file
# Compilation finished for 15 codes: 2 error(s).
#
# =================================================

# %%
import subprocess

print('Executing codes...')

for executable in list(Path(executables_path).rglob('*.exec')):    
    student_id = os.path.basename(executable).split('.exec')[0]
        
    print(f'Running {student_id}\'s codes')        
        
    for test_file in tests_path.rglob('*.txt'):
        test_name = os.path.basename(test_file).split('.txt')[0]
        
        test_num = test_name[2:]
        
        output_dir = os.path.join(outputs_path, test_name)
        os.makedirs(output_dir, exist_ok=True)
        
        output_path = os.path.join(output_dir, f'output-{student_id}.txt')
        
        input_file = open(test_file)
        output_file = open(output_path, 'w')
        
        try:
            subprocess.run([executable], stdin=input_file, stdout=output_file, timeout=time_limit, check=True)
            output_file.close()
        except subprocess.TimeoutExpired:
            print(f'Time limit exceeded on test {test_name}')
            final_results[student_id]['tests'][test_num] = {'score': 0, 'cost': None, 'status': 'Time limit'}
            os.remove(output_path)
        except subprocess.CalledProcessError:
            print(f'Runtime error on test {test_name}')
            final_results[student_id]['tests'][test_num] = {'score': 0, 'cost': None, 'status': 'Runtime Error'}
            os.remove(output_path)
        
        input_file.close()
        
print('\n=================================================\n')
# Out:
# Executing codes...
# Running 97105696's codes
# Running 97110206's codes
# Running 96101262's codes
# Running 97110155's codes
# Running 98209048's codes
# Running 97100581's codes
# Running 97102441's codes
# Running 96105948's codes
# Time limit exceeded on test in9
# Time limit exceeded on test in8
# Time limit exceeded on test in18
# Time limit exceeded on test in19
# Time limit exceeded on test in20
# Time limit exceeded on test in12
# Time limit exceeded on test in13
# Time limit exceeded on test in11
# Time limit exceeded on test in10
# Time limit exceeded on test in14
# Time limit exceeded on test in15
# Time limit exceeded on test in17
# Time limit exceeded on test in16
# Time limit exceeded on test in3
# Time limit exceeded on test in2
# Time limit exceeded on test in5
# Time limit exceeded on test in4
# Time limit exceeded on test in6
# Time limit exceeded on test in7
# Running 95108008's codes
# Time limit exceeded on test in18
# Time limit exceeded on test in19
# Time limit exceeded on test in20
# Time limit exceeded on test in12
# Time limit exceeded on test in13
# Time limit exceeded on test in11
# Time limit exceeded on test in10
# Time limit exceeded on test in14
# Time limit exceeded on test in15
# Time limit exceeded on test in17
# Time limit exceeded on test in16
# Time limit exceeded on test in1
# Time limit exceeded on test in4
# Running 95109383's codes
# Running 96105886's codes
# Time limit exceeded on test in9
# Time limit exceeded on test in12
# Time limit exceeded on test in15
# Time limit exceeded on test in1
# Time limit exceeded on test in6
# Running 96109606's codes
# Running 96110797's codes
#
# =================================================

# %%
all_judge = list(Path(working_directory).rglob('judge.exec'))  
if len(all_judge) != 1:
    print("wtf man")
judge = all_judge[0]

# %%
print(working_directory)
# Out:
# /Users/kianooshabbasi/Downloads/hello

# %%
judge_files = list(Path(working_directory).rglob('./judge'))

# %%
print(judge_files)
# Out:
# [PosixPath('/Users/kianooshabbasi/Downloads/hello/judge')]

# %%
cost = {}
for s in students:
    cost[s] = {}

for test in list(Path(outputs_path).rglob('in*')):
    this_test = os.path.basename(test) 
    test_num = this_test[2:]
    
    input_file = os.path.join(tests_path, this_test + '.txt')
    
    valid_submissions = list(test.rglob('output*.txt'))
    print("Seeing submissions output for test ", test_num, "\n")

    for student_output in valid_submissions:
        student_id = student_output.name.split('output-')[1].split('.txt')[0]
        
        try:
            out_path = os.path.join(test, f'checker-{student_id}.txt')
            log_path = os.path.join(test, f'log-{student_id}.txt')
            out_file = open(out_path, 'w')
            log_file = open(log_path, 'w')
            
            subprocess.run([judge, input_file, student_output], timeout=2, stdout=out_file, stderr=log_file, check=True)
            
            with open(out_path, "r") as f:
                checker_out = f.read()
            
            out_file.close()
            log_file.close()
            
            cost[student_id][test_num] = int(checker_out)
            print(f"{student_id}'s cost is {checker_out}")
        except subprocess.TimeoutExpired:
            print(f'Time limit exceeded on checker. its not normal')
            os.remove(log_file)
        except subprocess.CalledProcessError:
            print(f'Runtime error on checker. its not normal')
            os.remove(log_file)
# Out:
# Seeing submissions output for test  5
#
# 97110206's cost is 7370954
#
# 95108008's cost is 8230768
#
# 97105696's cost is 8995685
#
# 96110797's cost is 9259027
#
# 97102441's cost is 10190081
#
# 98209048's cost is 12975476
#
# 96101262's cost is 11213666
#
# 96109606's cost is 8180554
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 14326718
#
# 97100581's cost is 7370954
#
# Seeing submissions output for test  2
#
# 97110206's cost is 101
#
# 95108008's cost is 95
#
# 97105696's cost is 109
#
# 96110797's cost is 142
#
# 97102441's cost is 98
#
# 98209048's cost is -1
#
# 96101262's cost is 189
#
# 96109606's cost is 89
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 247
#
# 97100581's cost is 84
#
# Seeing submissions output for test  3
#
# 97110206's cost is 5060944
#
# 95108008's cost is 8080744
#
# 97105696's cost is 11141192
#
# 96110797's cost is 7070784
#
# 97102441's cost is 6080948
#
# 98209048's cost is -1
#
# 96101262's cost is 911070212
#
# 96109606's cost is 9140968
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 406060944
#
# 97100581's cost is 9140956
#
# Seeing submissions output for test  4
#
# 97110206's cost is 27909106
#
# 97105696's cost is 14030455
#
# 96110797's cost is 40116699
#
# 97102441's cost is 16711318
#
# 98209048's cost is -1
#
# 96101262's cost is 53679213
#
# 96109606's cost is 28391231
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 65834890
#
# 97100581's cost is 28280631
#
# Seeing submissions output for test  19
#
# 97110206's cost is 55653
#
# 97105696's cost is 117949
#
# 96110797's cost is 92234
#
# 97102441's cost is 65926
#
# 98209048's cost is 159906
#
# 96101262's cost is 108160
#
# 96109606's cost is 72448
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 128910
#
# 97100581's cost is 62412
#
# Seeing submissions output for test  17
#
# 97110206's cost is 33632916
#
# 97105696's cost is 69326324
#
# 96110797's cost is 66283665
#
# 97102441's cost is 32833107
#
# 98209048's cost is 59610320
#
# 96101262's cost is 131731714
#
# 96109606's cost is 43388350
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 118814132
#
# 97100581's cost is 34800158
#
# Seeing submissions output for test  10
#
# 97110206's cost is 25033
#
# 97105696's cost is 28227
#
# 96110797's cost is 44102
#
# 97102441's cost is 24449
#
# 98209048's cost is 27018
#
# 96101262's cost is 60603
#
# 96109606's cost is 28543
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 75240
#
# 97100581's cost is 23933
#
# Seeing submissions output for test  11
#
# 97110206's cost is 27729532
#
# 97105696's cost is 39399291
#
# 96110797's cost is 47298617
#
# 97102441's cost is 38330237
#
# 98209048's cost is 57820831
#
# 96101262's cost is 56839921
#
# 96109606's cost is 35557494
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 69842556
#
# 97100581's cost is 30494820
#
# Seeing submissions output for test  16
#
# 97110206's cost is 43057
#
# 97105696's cost is 65506
#
# 96110797's cost is 98703
#
# 97102441's cost is 58956
#
# 98209048's cost is 149721
#
# 96101262's cost is 132151
#
# 96109606's cost is 69403
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 161151
#
# 97100581's cost is 56140
#
# Seeing submissions output for test  20
#
# 97110206's cost is 48674451
#
# 97105696's cost is 70713413
#
# 96110797's cost is 115780420
#
# 97102441's cost is 58070640
#
# 98209048's cost is 68599123
#
# 96101262's cost is 204418584
#
# 96109606's cost is 77213686
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 200849376
#
# 97100581's cost is 58779051
#
# Seeing submissions output for test  18
#
# 97110206's cost is 62
#
# 97105696's cost is 103
#
# 96110797's cost is 107
#
# 97102441's cost is 74
#
# 98209048's cost is -1
#
# 96101262's cost is 310
#
# 96109606's cost is 69
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 289
#
# 97100581's cost is 60
#
# Seeing submissions output for test  1
#
# 97110206's cost is 3000000022
#
# 97105696's cost is 3000000022
#
# 96105948's cost is -1
#
# 96110797's cost is 3000000033
#
# 97102441's cost is 3000000024
#
# 98209048's cost is 3000000033
#
# 96101262's cost is 4000000044
#
# 96109606's cost is 3000000042
#
# 95109383's cost is -1
#
# 97110155's cost is 4000000066
#
# 97100581's cost is 3000000022
#
# Seeing submissions output for test  6
#
# 97110206's cost is 124
#
# 95108008's cost is 121
#
# 97105696's cost is 139
#
# 96110797's cost is 177
#
# 97102441's cost is 148
#
# 98209048's cost is -1
#
# 96101262's cost is 206
#
# 96109606's cost is 155
#
# 95109383's cost is -1
#
# 97110155's cost is 302
#
# 97100581's cost is 139
#
# Seeing submissions output for test  8
#
# 97110206's cost is 15486558
#
# 95108008's cost is 18604354
#
# 97105696's cost is 19757921
#
# 96110797's cost is 24096611
#
# 97102441's cost is 23179526
#
# 98209048's cost is 16101548
#
# 96101262's cost is 26350891
#
# 96109606's cost is 21234703
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 35967475
#
# 97100581's cost is 19138052
#
# Seeing submissions output for test  9
#
# 97110206's cost is 140
#
# 95108008's cost is 120
#
# 97105696's cost is 142
#
# 96110797's cost is 147
#
# 97102441's cost is 123
#
# 98209048's cost is -1
#
# 96101262's cost is 175
#
# 96109606's cost is 119
#
# 95109383's cost is -1
#
# 97110155's cost is 241
#
# 97100581's cost is 107
#
# Seeing submissions output for test  7
#
# 97110206's cost is 13986
#
# 95108008's cost is 12705
#
# 97105696's cost is 11445
#
# 96110797's cost is 17050
#
# 97102441's cost is 12372
#
# 98209048's cost is -1
#
# 96101262's cost is 22715
#
# 96109606's cost is 14618
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 29938
#
# 97100581's cost is 12686
#
# Seeing submissions output for test  13
#
# 97110206's cost is 23267
#
# 97105696's cost is 23489
#
# 96110797's cost is 38611
#
# 97102441's cost is 25230
#
# 98209048's cost is 68907
#
# 96101262's cost is 64509
#
# 96109606's cost is 26371
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 72936
#
# 97100581's cost is 21803
#
# Seeing submissions output for test  14
#
# 97110206's cost is 44948354
#
# 97105696's cost is 61067630
#
# 96110797's cost is 68256503
#
# 97102441's cost is 45644876
#
# 98209048's cost is 108992681
#
# 96101262's cost is 81388504
#
# 96109606's cost is 48402270
#
# 95109383's cost is -1
#
# 96105886's cost is -1
#
# 97110155's cost is 111278128
#
# 97100581's cost is 40521743
#
# Seeing submissions output for test  15
#
# 97110206's cost is 248
#
# 97105696's cost is 520
#
# 96110797's cost is 574
#
# 97102441's cost is 338
#
# 98209048's cost is -1
#
# 96101262's cost is 964
#
# 96109606's cost is 404
#
# 95109383's cost is -1
#
# 97110155's cost is 1021
#
# 97100581's cost is 264
#
# Seeing submissions output for test  12
#
# 97110206's cost is 279
#
# 97105696's cost is 516
#
# 96110797's cost is 426
#
# 97102441's cost is 294
#
# 98209048's cost is -1
#
# 96101262's cost is 474
#
# 96109606's cost is 312
#
# 95109383's cost is -1
#
# 97110155's cost is 654
#
# 97100581's cost is 258

# %%
def prob(ri, rj):
    delta = (rj - ri) / 400.
    return 1.0 / (1.0 + 10**(delta))

def get_new_ratings(rate, standing): # current rates, standing of student ids in latest round
    seed = {}
    for i in rate:
        seed[i] = 1
        for j in rate:
            if i == j:
                continue
            seed[i] += prob(rate[j], rate[i])
    new_rates = {}
    for idx, u in enumerate(standing): # u: user
        lo, hi = 10, 4000
        m_i = math.sqrt((idx + 1) * seed[u])
        while(hi - lo > 1):
            mid = (hi + lo)//2
            new_seed = 1
            for j in rate:
                if j == u:
                    continue
                new_seed += prob(rate[j], mid)
            
            if new_seed < m_i: # over valued rating
                hi = mid
            else:
                lo = mid
        R = (hi + lo) * 0.5
        d_i = (R - rate[u]) * 0.5
        new_rates[u] = int(rate[u] + d_i)
    return new_rates

def return_student_ranking(all_scores, all_tests, test_weights, use_w = False):
    total_score = {student: 0 for student in students}
    for t in all_tests:
        results = []
        for s in students:
            if not t in all_scores[s]:
                continue
            res = all_scores[s][t]
            if res != -1:
                results.append((res, s))
        results.sort()
        first_three = results
        if len(results) > 3:
            first_three = first_three[:3]
        C = []
        for i in range(len(first_three)):
            C.append(first_three[i][0])
        Cm = np.mean(C)
        for s in students:
            if not t in all_scores[s]:
                continue
            res = all_scores[s][t]
            if res == -1:
                final_results[s]['tests'][t] = {'score': 0, 'cost': None, 'status': 'Invalid'}
                continue
            X = test_weights[t] * min(1, (Cm/res)**(1/3))
            final_results[s]['tests'][t] = {'score': round(X, 3), 'cost': res, 'status': 'Success'}
            total_score[s] += X
    sorted_d = sorted(total_score.items(), key=operator.itemgetter(1), reverse=True)
    rank = []
    for i, (student, score) in enumerate(sorted_d):
        rank.append(student)
        final_results[student]['final_score'] = round(score, 3)
        final_results[student]['ranking'] = i + 1
    print('Rank', rank)
    return rank

def update_ratings():
    rating_files = list(Path(working_directory).rglob(rating_file))
    rate = {}
    if len(rating_files) == 0:
        print("NO ratings will set every one to 1500")
        for s in students:
            rate[s] = 1500
    else:
        with open(rating_file, 'r', encoding='utf-8') as fp:
            rate = json.load(fp)
    print("previous rates -----")
    print(rate)
    for x, y in rate.items():
        final_results[x]['prev_rating'] = y
    standing = return_student_ranking(cost, all_tests, {str(i): 100 for i in range(30)}, False)
    new_rates = get_new_ratings(rate, standing)
    destination = f"rating-{division}.json"
    print("new rates -----")
    print(new_rates)
    for x, y in new_rates.items():
        final_results[x]['new_rating'] = y
    with open(destination, 'w', encoding='utf-8') as fp:
        json.dump(new_rates, fp)

# %%
update_ratings()
# Out:
# NO ratings will set every one to 1500
# previous rates -----
# {'97100581': 1500, '96105886': 1500, '96110797': 1500, '96109606': 1500, '96109663': 1500, '96105948': 1500, '97102441': 1500, '97105696': 1500, '98209048': 1500, '97110206': 1500, '95109383': 1500, '95108008': 1500, '96101262': 1500, '97110155': 1500, 'dummy': 1500}
# Rank ['97110206', '97100581', '97102441', '96109606', '97105696', '96110797', '96101262', '97110155', '98209048', '95108008', '96105886', '96109663', '96105948', '95109383', 'dummy']
# new rates -----
# {'97110206': 1664, '97100581': 1612, '97102441': 1582, '96109606': 1560, '97105696': 1542, '96110797': 1526, '96101262': 1512, '97110155': 1500, '98209048': 1487, '95108008': 1476, '96105886': 1465, '96109663': 1454, '96105948': 1443, '95109383': 1432, 'dummy': 1421}

# %%
data = sorted(final_results.items(), key= lambda item: item[1]['ranking'])

# %%
data
# Out:
# [('97110206',
#   {'ranking': 1,
#    'tests': {'9': {'score': 93.744, 'cost': 140, 'status': 'Success'},
#     '8': {'score': 100, 'cost': 15486558, 'status': 'Success'},
#     '18': {'score': 100, 'cost': 62, 'status': 'Success'},
#     '19': {'score': 100, 'cost': 55653, 'status': 'Success'},
#     '20': {'score': 100, 'cost': 48674451, 'status': 'Success'},
#     '12': {'score': 99.76, 'cost': 279, 'status': 'Success'},
#     '13': {'score': 99.403, 'cost': 23267, 'status': 'Success'},
#     '11': {'score': 100, 'cost': 27729532, 'status': 'Success'},
#     '10': {'score': 99.247, 'cost': 25033, 'status': 'Success'},
#     '14': {'score': 99.069, 'cost': 44948354, 'status': 'Success'},
#     '15': {'score': 100, 'cost': 248, 'status': 'Success'},
#     '17': {'score': 100, 'cost': 33632916, 'status': 'Success'},
#     '16': {'score': 100, 'cost': 43057, 'status': 'Success'},
#     '3': {'score': 100, 'cost': 5060944, 'status': 'Success'},
#     '2': {'score': 95.991, 'cost': 101, 'status': 'Success'},
#     '1': {'score': 100, 'cost': 3000000022, 'status': 'Success'},
#     '5': {'score': 100, 'cost': 7370954, 'status': 'Success'},
#     '4': {'score': 88.811, 'cost': 27909106, 'status': 'Success'},
#     '6': {'score': 100, 'cost': 124, 'status': 'Success'},
#     '7': {'score': 95.464, 'cost': 13986, 'status': 'Success'}},
#    'final_score': 1971.49,
#    'prev_rating': 1500,
#    'new_rating': 1664}),
#  ('97100581',
#   {'ranking': 2,
#    'tests': {'9': {'score': 100, 'cost': 107, 'status': 'Success'},
#     '8': {'score': 95.618, 'cost': 19138052, 'status': 'Success'},
#     '18': {'score': 100, 'cost': 60, 'status': 'Success'},
#     '19': {'score': 99.419, 'cost': 62412, 'status': 'Success'},
#     '20': {'score': 97.913, 'cost': 58779051, 'status': 'Success'},
#     '12': {'score': 100, 'cost': 258, 'status': 'Success'},
#     '13': {'score': 100, 'cost': 21803, 'status': 'Success'},
#     '11': {'score': 100, 'cost': 30494820, 'status': 'Success'},
#     '10': {'score': 100, 'cost': 23933, 'status': 'Success'},
#     '14': {'score': 100, 'cost': 40521743, 'status': 'Success'},
#     '15': {'score': 100, 'cost': 264, 'status': 'Success'},
#     '17': {'score': 98.989, 'cost': 34800158, 'status': 'Success'},
#     '16': {'score': 97.925, 'cost': 56140, 'status': 'Success'},
#     '3': {'score': 87.248, 'cost': 9140956, 'status': 'Success'},
#     '2': {'score': 100, 'cost': 84, 'status': 'Success'},
#     '1': {'score': 100, 'cost': 3000000022, 'status': 'Success'},
#     '5': {'score': 100, 'cost': 7370954, 'status': 'Success'},
#     '4': {'score': 88.421, 'cost': 28280631, 'status': 'Success'},
#     '6': {'score': 97.289, 'cost': 139, 'status': 'Success'},
#     '7': {'score': 98.619, 'cost': 12686, 'status': 'Success'}},
#    'final_score': 1961.441,
#    'prev_rating': 1500,
#    'new_rating': 1612}),
#  ('97102441',
#   {'ranking': 3,
#    'tests': {'9': {'score': 97.878, 'cost': 123, 'status': 'Success'},
#     '8': {'score': 89.702, 'cost': 23179526, 'status': 'Success'},
#     '18': {'score': 95.11, 'cost': 74, 'status': 'Success'},
#     '19': {'score': 97.62, 'cost': 65926, 'status': 'Success'},
#     '20': {'score': 98.309, 'cost': 58070640, 'status': 'Success'},
#     '12': {'score': 98.034, 'cost': 294, 'status': 'Success'},
#     '13': {'score': 96.755, 'cost': 25230, 'status': 'Success'},
#     '11': {'score': 93.43, 'cost': 38330237, 'status': 'Success'},
#     '10': {'score': 100, 'cost': 24449, 'status': 'Success'},
#     '14': {'score': 98.563, 'cost': 45644876, 'status': 'Success'},
#     '15': {'score': 94.289, 'cost': 338, 'status': 'Success'},
#     '17': {'score': 100, 'cost': 32833107, 'status': 'Success'},
#     '16': {'score': 96.341, 'cost': 58956, 'status': 'Success'},
#     '3': {'score': 99.945, 'cost': 6080948, 'status': 'Success'},
#     '2': {'score': 96.961, 'cost': 98, 'status': 'Success'},
#     '1': {'score': 100.0, 'cost': 3000000024, 'status': 'Success'},
#     '5': {'score': 90.849, 'cost': 10190081, 'status': 'Success'},
#     '4': {'score': 100, 'cost': 16711318, 'status': 'Success'},
#     '6': {'score': 95.276, 'cost': 148, 'status': 'Success'},
#     '7': {'score': 99.446, 'cost': 12372, 'status': 'Success'}},
#    'final_score': 1938.508,
#    'prev_rating': 1500,
#    'new_rating': 1582}),
#  ('96109606',
#   {'ranking': 4,
#    'tests': {'9': {'score': 98.962, 'cost': 119, 'status': 'Success'},
#     '8': {'score': 92.361, 'cost': 21234703, 'status': 'Success'},
#     '18': {'score': 97.354, 'cost': 69, 'status': 'Success'},
#     '19': {'score': 94.598, 'cost': 72448, 'status': 'Success'},
#     '20': {'score': 89.402, 'cost': 77213686, 'status': 'Success'},
#     '12': {'score': 96.111, 'cost': 312, 'status': 'Success'},
#     '13': {'score': 95.339, 'cost': 26371, 'status': 'Success'},
#     '11': {'score': 95.798, 'cost': 35557494, 'status': 'Success'},
#     '10': {'score': 94.999, 'cost': 28543, 'status': 'Success'},
#     '14': {'score': 96.654, 'cost': 48402270, 'status': 'Success'},
#     '15': {'score': 88.846, 'cost': 404, 'status': 'Success'},
#     '17': {'score': 91.972, 'cost': 43388350, 'status': 'Success'},
#     '16': {'score': 91.242, 'cost': 69403, 'status': 'Success'},
#     '3': {'score': 87.248, 'cost': 9140968, 'status': 'Success'},
#     '2': {'score': 100, 'cost': 89, 'status': 'Success'},
#     '1': {'score': 100.0, 'cost': 3000000042, 'status': 'Success'},
#     '5': {'score': 97.751, 'cost': 8180554, 'status': 'Success'},
#     '4': {'score': 88.306, 'cost': 28391231, 'status': 'Success'},
#     '6': {'score': 93.819, 'cost': 155, 'status': 'Success'},
#     '7': {'score': 94.068, 'cost': 14618, 'status': 'Success'}},
#    'final_score': 1884.832,
#    'prev_rating': 1500,
#    'new_rating': 1560}),
#  ('97105696',
#   {'ranking': 5,
#    'tests': {'9': {'score': 93.302, 'cost': 142, 'status': 'Success'},
#     '8': {'score': 94.607, 'cost': 19757921, 'status': 'Success'},
#     '18': {'score': 85.184, 'cost': 103, 'status': 'Success'},
#     '19': {'score': 80.413, 'cost': 117949, 'status': 'Success'},
#     '20': {'score': 92.062, 'cost': 70713413, 'status': 'Success'},
#     '12': {'score': 81.272, 'cost': 516, 'status': 'Success'},
#     '13': {'score': 99.089, 'cost': 23489, 'status': 'Success'},
#     '11': {'score': 92.577, 'cost': 39399291, 'status': 'Success'},
#     '10': {'score': 95.353, 'cost': 28227, 'status': 'Success'},
#     '14': {'score': 89.449, 'cost': 61067630, 'status': 'Success'},
#     '15': {'score': 81.677, 'cost': 520, 'status': 'Success'},
#     '17': {'score': 78.671, 'cost': 69326324, 'status': 'Success'},
#     '16': {'score': 93.016, 'cost': 65506, 'status': 'Success'},
#     '3': {'score': 81.678, 'cost': 11141192, 'status': 'Success'},
#     '2': {'score': 93.583, 'cost': 109, 'status': 'Success'},
#     '1': {'score': 100, 'cost': 3000000022, 'status': 'Success'},
#     '5': {'score': 94.704, 'cost': 8995685, 'status': 'Success'},
#     '4': {'score': 100, 'cost': 14030455, 'status': 'Success'},
#     '6': {'score': 97.289, 'cost': 139, 'status': 'Success'},
#     '7': {'score': 100, 'cost': 11445, 'status': 'Success'}},
#    'final_score': 1823.926,
#    'prev_rating': 1500,
#    'new_rating': 1542}),
#  ('96110797',
#   {'ranking': 6,
#    'tests': {'9': {'score': 92.231, 'cost': 147, 'status': 'Success'},
#     '8': {'score': 88.55, 'cost': 24096611, 'status': 'Success'},
#     '18': {'score': 84.109, 'cost': 107, 'status': 'Success'},
#     '19': {'score': 87.283, 'cost': 92234, 'status': 'Success'},
#     '20': {'score': 78.109, 'cost': 115780420, 'status': 'Success'},
#     '12': {'score': 86.634, 'cost': 426, 'status': 'Success'},
#     '13': {'score': 83.961, 'cost': 38611, 'status': 'Success'},
#     '11': {'score': 87.106, 'cost': 47298617, 'status': 'Success'},
#     '10': {'score': 82.174, 'cost': 44102, 'status': 'Success'},
#     '14': {'score': 86.191, 'cost': 68256503, 'status': 'Success'},
#     '15': {'score': 79.031, 'cost': 574, 'status': 'Success'},
#     '17': {'score': 79.857, 'cost': 66283665, 'status': 'Success'},
#     '16': {'score': 81.135, 'cost': 98703, 'status': 'Success'},
#     '3': {'score': 95.045, 'cost': 7070784, 'status': 'Success'},
#     '2': {'score': 85.686, 'cost': 142, 'status': 'Success'},
#     '1': {'score': 100.0, 'cost': 3000000033, 'status': 'Success'},
#     '5': {'score': 93.798, 'cost': 9259027, 'status': 'Success'},
#     '4': {'score': 78.694, 'cost': 40116699, 'status': 'Success'},
#     '6': {'score': 89.759, 'cost': 177, 'status': 'Success'},
#     '7': {'score': 89.364, 'cost': 17050, 'status': 'Success'}},
#    'final_score': 1728.716,
#    'prev_rating': 1500,
#    'new_rating': 1526}),
#  ('96101262',
#   {'ranking': 7,
#    'tests': {'9': {'score': 87.024, 'cost': 175, 'status': 'Success'},
#     '8': {'score': 85.949, 'cost': 26350891, 'status': 'Success'},
#     '18': {'score': 59.0, 'cost': 310, 'status': 'Success'},
#     '19': {'score': 82.769, 'cost': 108160, 'status': 'Success'},
#     '20': {'score': 64.626, 'cost': 204418584, 'status': 'Success'},
#     '12': {'score': 83.605, 'cost': 474, 'status': 'Success'},
#     '13': {'score': 70.758, 'cost': 64509, 'status': 'Success'},
#     '11': {'score': 81.931, 'cost': 56839921, 'status': 'Success'},
#     '10': {'score': 73.913, 'cost': 60603, 'status': 'Success'},
#     '14': {'score': 81.281, 'cost': 81388504, 'status': 'Success'},
#     '15': {'score': 66.488, 'cost': 964, 'status': 'Success'},
#     '17': {'score': 63.516, 'cost': 131731714, 'status': 'Success'},
#     '16': {'score': 73.614, 'cost': 132151, 'status': 'Success'},
#     '3': {'score': 18.818, 'cost': 911070212, 'status': 'Success'},
#     '2': {'score': 77.896, 'cost': 189, 'status': 'Success'},
#     '1': {'score': 90.856, 'cost': 4000000044, 'status': 'Success'},
#     '5': {'score': 87.996, 'cost': 11213666, 'status': 'Success'},
#     '4': {'score': 71.414, 'cost': 53679213, 'status': 'Success'},
#     '6': {'score': 85.332, 'cost': 206, 'status': 'Success'},
#     '7': {'score': 81.214, 'cost': 22715, 'status': 'Success'}},
#    'final_score': 1488.001,
#    'prev_rating': 1500,
#    'new_rating': 1512}),
#  ('97110155',
#   {'ranking': 8,
#    'tests': {'9': {'score': 78.219, 'cost': 241, 'status': 'Success'},
#     '8': {'score': 77.482, 'cost': 35967475, 'status': 'Success'},
#     '18': {'score': 60.396, 'cost': 289, 'status': 'Success'},
#     '19': {'score': 78.066, 'cost': 128910, 'status': 'Success'},
#     '20': {'score': 65.006, 'cost': 200849376, 'status': 'Success'},
#     '12': {'score': 75.099, 'cost': 654, 'status': 'Success'},
#     '13': {'score': 67.92, 'cost': 72936, 'status': 'Success'},
#     '11': {'score': 76.494, 'cost': 69842556, 'status': 'Success'},
#     '10': {'score': 68.771, 'cost': 75240, 'status': 'Success'},
#     '14': {'score': 73.233, 'cost': 111278128, 'status': 'Success'},
#     '15': {'score': 65.226, 'cost': 1021, 'status': 'Success'},
#     '17': {'score': 65.739, 'cost': 118814132, 'status': 'Success'},
#     '16': {'score': 68.903, 'cost': 161151, 'status': 'Success'},
#     '3': {'score': 24.635, 'cost': 406060944, 'status': 'Success'},
#     '2': {'score': 71.248, 'cost': 247, 'status': 'Success'},
#     '1': {'score': 90.856, 'cost': 4000000066, 'status': 'Success'},
#     '5': {'score': 81.096, 'cost': 14326718, 'status': 'Success'},
#     '4': {'score': 66.716, 'cost': 65834890, 'status': 'Success'},
#     '6': {'score': 75.116, 'cost': 302, 'status': 'Success'},
#     '7': {'score': 74.073, 'cost': 29938, 'status': 'Success'}},
#    'final_score': 1404.297,
#    'prev_rating': 1500,
#    'new_rating': 1500}),
#  ('98209048',
#   {'ranking': 9,
#    'tests': {'9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '8': {'score': 100, 'cost': 16101548, 'status': 'Success'},
#     '18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '19': {'score': 72.656, 'cost': 159906, 'status': 'Success'},
#     '20': {'score': 92.998, 'cost': 68599123, 'status': 'Success'},
#     '12': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '13': {'score': 69.219, 'cost': 68907, 'status': 'Success'},
#     '11': {'score': 81.465, 'cost': 57820831, 'status': 'Success'},
#     '10': {'score': 96.754, 'cost': 27018, 'status': 'Success'},
#     '14': {'score': 73.741, 'cost': 108992681, 'status': 'Success'},
#     '15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '17': {'score': 82.732, 'cost': 59610320, 'status': 'Success'},
#     '16': {'score': 70.614, 'cost': 149721, 'status': 'Success'},
#     '3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '1': {'score': 100.0, 'cost': 3000000033, 'status': 'Success'},
#     '5': {'score': 83.818, 'cost': 12975476, 'status': 'Success'},
#     '4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '6': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '7': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 923.998,
#    'prev_rating': 1500,
#    'new_rating': 1487}),
#  ('95108008',
#   {'ranking': 10,
#    'tests': {'18': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '19': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '12': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '13': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '11': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '10': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '14': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '17': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '16': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '1': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '4': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '9': {'score': 98.687, 'cost': 120, 'status': 'Success'},
#     '8': {'score': 96.524, 'cost': 18604354, 'status': 'Success'},
#     '3': {'score': 90.908, 'cost': 8080744, 'status': 'Success'},
#     '2': {'score': 97.971, 'cost': 95, 'status': 'Success'},
#     '5': {'score': 97.551, 'cost': 8230768, 'status': 'Success'},
#     '6': {'score': 100, 'cost': 121, 'status': 'Success'},
#     '7': {'score': 98.57, 'cost': 12705, 'status': 'Success'}},
#    'final_score': 680.21,
#    'prev_rating': 1500,
#    'new_rating': 1476}),
#  ('96105886',
#   {'ranking': 11,
#    'tests': {'9': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '12': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '1': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '6': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '14': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '7': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1465}),
#  ('96109663',
#   {'ranking': 12,
#    'tests': {'9': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '8': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '18': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '19': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '20': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '12': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '13': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '11': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '10': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '14': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '15': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '17': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '16': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '3': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '2': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '1': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '5': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '4': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '6': {'score': 0, 'cost': None, 'status': 'Compiler Error'},
#     '7': {'score': 0, 'cost': None, 'status': 'Compiler Error'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1454}),
#  ('96105948',
#   {'ranking': 13,
#    'tests': {'9': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '8': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '18': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '19': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '20': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '12': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '13': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '11': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '10': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '14': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '15': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '17': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '16': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '3': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '2': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '5': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '4': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '6': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '7': {'score': 0, 'cost': None, 'status': 'Time limit'},
#     '1': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1443}),
#  ('95109383',
#   {'ranking': 14,
#    'tests': {'9': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '8': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '18': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '19': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '20': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '12': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '13': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '11': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '10': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '14': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '15': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '17': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '16': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '3': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '2': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '1': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '5': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '4': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '6': {'score': 0, 'cost': None, 'status': 'Invalid'},
#     '7': {'score': 0, 'cost': None, 'status': 'Invalid'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1432}),
#  ('dummy',
#   {'ranking': 15,
#    'tests': {'9': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '8': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '18': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '19': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '20': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '12': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '13': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '11': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '10': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '14': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '15': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '17': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '16': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '3': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '2': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '1': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '5': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '4': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '6': {'score': 0, 'cost': None, 'status': 'No Submission'},
#     '7': {'score': 0, 'cost': None, 'status': 'No Submission'}},
#    'final_score': 0,
#    'prev_rating': 1500,
#    'new_rating': 1421})]

# %%
import xlsxwriter


def export_excel(data):

    workbook = xlsxwriter.Workbook(f'result-{division}.xlsx')
    worksheet = workbook.add_worksheet()
    cell_format1 = workbook.add_format({'bg_color': 'green'})
    cell_format2 = workbook.add_format({'bg_color': 'red'})

    col = 0
    worksheet.write(0, 0, "Ranking")
    worksheet.write(0, 1, "Student ID")
    worksheet.write(0, 2, "Final score")
    worksheet.write(0, 3, "Prev rating")
    worksheet.write(0, 4, "Rating change")
    worksheet.write(0, 5, "New rating")
    worksheet.write(0, 6, "")

    for i in range(1,21):
        worksheet.write(0, i + 6, f"Test {i} score\n(cost)")
        
    for i in range(len(data)):
        col = 0
        worksheet.write(2*i+1, col, data[i][1]["ranking"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][0])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["final_score"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["prev_rating"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["new_rating"] - data[i][1]["prev_rating"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, data[i][1]["new_rating"])
        worksheet.write(2*i+2, col, "")
        col += 1
        worksheet.write(2*i+1, col, "")
        worksheet.write(2*i+2, col, "")
        col += 1
        for num in sorted(data[i][1]["tests"], key=int):
            worksheet.write(2 * i + 1, col, data[i][1]["tests"][num]["score"])
            if data[i][1]["tests"][num]['status'] == "Success":
                worksheet.write(2 * i + 2, col, f'({data[i][1]["tests"][num]["cost"]})')
            else:
                worksheet.write(2 * i + 2, col, f'({data[i][1]["tests"][num]["status"]})')
        
            col += 1

    workbook.close()

# %%
export_excel(data)
